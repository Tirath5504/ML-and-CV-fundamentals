# %% [markdown]
# # **Task 3**
#
# ## **DJS Synapse Learning Period**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Unsupervised Learning**
#
# Clustering is an unsupervised learning technique used to group similar data points together. It's widely used in various applications like customer segmentation, anomaly detection, and more. In this task, we'll explore different clustering algorithms and visualize their results.
#
# We will work with the **Samsung Human Activity Recognition dataset**. The data comes from the accelerometers and gyros of Samsung mobile phones, the type of activity of a person with a phone in his pocket is also known - whether he walked, stood, lay, sat or walked up or down the stairs.
#
# We imagine that the type of activity is unknown to us (unlabelled), and we will try to cluster people purely on the basis of available features.
#
# The dataset that will be used can be found here - [DATA](https://drive.google.com/drive/folders/1K2IP3MOVwDQp3UWTCEUae-4roZrE1Rfv?usp=drive_link)

# %% [markdown]
# # Importing and Installing all the necessary libaries

# %%
# !pip install exkmc yellowbrick -q

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

from sklearn.cluster import KMeans, AgglomerativeClustering, DBSCAN, MeanShift, SpectralClustering
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

from yellowbrick.cluster import KElbowVisualizer
from ExKMC.Tree import Tree

from IPython.display import Image,display
from ipywidgets import interact
import os

import warnings
warnings.filterwarnings("ignore")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.6/139.6 kB 3.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for exkmc (setup.py) ... done

# %% [markdown]
# Mount your google drive

# %%
# code here
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # Data Loading

# %% [markdown]
# Mention the path of dataset, 4 paths for the 4 different txt files.

# %%
# Mention the path in the strings below
samsung_train_path = '/content/gdrive/MyDrive/Synapse/Synapse - Week 3 - Unsupervised Learning/samsung_train.txt'
samsung_train_labels_path = '/content/gdrive/MyDrive/Synapse/Synapse - Week 3 - Unsupervised Learning/samsung_train_labels.txt'
samsung_test_path = '/content/gdrive/MyDrive/Synapse/Synapse - Week 3 - Unsupervised Learning/samsung_test.txt'
samsung_test_labels_path = '/content/gdrive/MyDrive/Synapse/Synapse - Week 3 - Unsupervised Learning/samsung_test_labels.txt'

# %% [markdown]
# This time we will be using np.loadtxt() for reading our data. Code for the same has been given (do not modify), but we expect you to understand the working of it.
#
# Ref.: https://www.geeksforgeeks.org/numpy-loadtxt-in-python/

# %%
# DO NOT MODIFY
X_train = np.loadtxt(samsung_train_path)
y_train = np.loadtxt(samsung_train_labels_path).astype(#fillhere
                                                       dtype=float)

X_test = np.loadtxt(samsung_test_path)
y_test = np.loadtxt(samsung_test_labels_path).astype(#fillhere
dtype=float)

# %% [markdown]
# Just to confirm that your data has been loaded properly, execute the below cell. You won't receive any error if everything is correct.
#
# NOTE: If you get an Assertion error, then you probably did something wrong above.

# %%
# Checking dimensions
assert(X_train.shape == (7352, 561) and y_train.shape == (7352,))
assert(X_test.shape == (2947, 561) and y_test.shape == (2947,))

# %% [markdown]
# # **Pre-processing**

# %% [markdown]
# For clustering, we do not need a target vector, so we'll work with the combination of training and test samples. Merge *X_train* with *X_test*, and *y_train* with *y_test*.
#
# Hint:
# 1. Merge X_train and X_test into X {use [np.vstack()](https://numpy.org/doc/stable/reference/generated/numpy.vstack.html)}
# 2. Merge y_train and y_test into y {use [np.hstack()](https://numpy.org/doc/stable/reference/generated/numpy.hstack.html)}

# %%
# Uncomment the below lines and code
X = np.vstack((X_train, X_test))
y = np.hstack((y_train, y_test))

# %% [markdown]
# Using numpy, print the unique values of the labels of the target class (i.e. "y").
#
# Ref.: https://www.geeksforgeeks.org/python-numpy-np-unique-method/

# %%
# code here
print(np.unique(y))
# Out:
# [1. 2. 3. 4. 5. 6.]

# %% [markdown]
# Store the size (or number) of unique values of the labels of the target class (i.e. "y") in a variable named n_classes.

# %%
# Uncomment the below line and code
n_classes = len(np.unique(y))

# %%
activities = [
    "walking",
    "going up the stairs",
    "going down the stairs",
    "sitting",
    "standing",
    "lying down"
]

# %% [markdown]
# Here the 6 labels (or classes) correspond to:
# - 1 - walking
# - 2 - going up the stairs
# - 3 - going down the stairs
# - 4 - sitting
# - 5 - standing
# - 6 - lying down
#
# So we wish to create 6 clusters where each cluster can represent one of the above activities.

# %% [markdown]
# Scale the sample (i.e. X) using [`StandardScaler()`](https://www.digitalocean.com/community/tutorials/standardscaler-function-in-python)

# %%
from sklearn.preprocessing import StandardScaler
# initialize an instance of StandardScaler()
scale = StandardScaler()
# use the above instance to fit_transform "X" and assign it into a new variable "X_scaled"
X_scaled = scale.fit_transform(X)

# %% [markdown]
# # **Dimensionality Reduction using PCA**

# %% [markdown]
# Ref.: https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.PCA.html

# %%
# Import PCA from sklearn.decomposition
from sklearn.decomposition import PCA

# %% [markdown]
# Reduce the number of dimensions using PCA,
#
# Hints:
# 1. Initialise instance of PCA and set *n_components* to 0.9 and *random_state* to 17.
# 2. Fit X_scaled over the PCA instance created
# 3. Transform X_scaled over the fitted PCA instance and store it in a variable named X_pca.
#
# Theory: https://www.analyticsvidhya.com/blog/2022/07/principal-component-analysis-beginner-friendly/ and https://en.wikipedia.org/wiki/Principal_component_analysis
#
# Theory + Implementation.: https://youtu.be/OFyyWcw2cyM (Jump to timestamp - 13:50 for PCA implementaion)

# %%
# code here
pc = PCA(n_components=0.9,random_state=17)
X_pca = pc.fit_transform(X_scaled)

# %% [markdown]
# Let's check the shape of X_pca.

# %%
# code here
X_pca.shape
# Should print (10299, 65) if everything is correct.
# Out:
# (10299, 65)

# %% [markdown]
# Shape of X was (10299, 561) i.e 561 dimensions
#
# Shape of X_pca is (10299, 65) i.e. 65 dimenisons
#
# Hence we have successfully reduced dimensions using PCA.

# %% [markdown]
# # K-Means Clustering (Partition-Based Clustering)

# %% [markdown]
# K-means clustering is an essential partitioning algorithm used to categorize a dataset into 'k' distinct, non-overlapping clusters. Each data point is assigned to the cluster with the nearest mean or centroid, symbolizing the cluster's center. The primary goal of the algorithm is to minimize the sum of squared distances between data points and their respective cluster centroids.
#
# For an in-depth exploration of K-means clustering, you can refer to this comprehensive article on Analytics Vidhya: [Comprehensive Guide to K-means Clustering](https://www.analyticsvidhya.com/blog/2019/08/comprehensive-guide-k-means-clustering/).
#
# For a deeper understanding of the mathematical underpinnings of K-means clustering, Wikipedia is a valuable resource. You can explore the Wikipedia page on K-means clustering for a detailed description: [K-means Clustering Wikipedia](https://en.wikipedia.org/wiki/K-means_clustering). This will help you grasp the mathematical intricacies of the algorithm and its applications in machine learning.

# %% [markdown]
# ### 2 Dimensional Visualization

# %%
## Perform K-Means clustering with interactive widget
def kmeans_clustering(num_clusters):
    kmeans = KMeans(n_clusters=num_clusters, random_state=42)
    kmeans_labels = kmeans.fit_predict(X_pca)

    plt.figure(figsize=(8, 6))
    plt.scatter(X_pca[:, 0], X_pca[:, 1], c=kmeans_labels, cmap='viridis', edgecolors='k')
    plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=200, c='red', marker='X', label='Centroids')
    plt.xlabel('Feature 1 (Standardized)')
    plt.ylabel('Feature 2 (Standardized)')
    plt.title('K-Means Clustering')
    plt.legend()
    plt.show()

low = 2
high = 6
scale = 1

interact(kmeans_clustering, num_clusters=(low,high,scale))
# Out:
# interactive(children=(IntSlider(value=4, description='num_clusters', max=6, min=2), Output()), _dom_classes=('…
# <function __main__.kmeans_clustering(num_clusters)>

# %% [markdown]
# ### 3 Dimensional Visualization

# %%
## Perform K-Means clustering with interactive widget
def kmeans_3d_clustering(num_clusters):
    kmeans_3d = KMeans(n_clusters=num_clusters, random_state=42)# Write Code Here
    kmeans_3d_labels = kmeans_3d.fit_predict(X_pca)# Write Code Here

    fig = plt.figure(figsize=(10, 8))
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(X_pca[:, 0], X_pca[:, 1], X_pca[:, 2], c=kmeans_3d_labels, cmap='viridis', edgecolors='k')
    ax.set_xlabel('Feature 1 (Standardized)')
    ax.set_ylabel('Feature 2 (Standardized)')
    ax.set_zlabel('Feature 3 (Standardized)')
    ax.set_title('Kmeans Clustering (3D)')
    plt.show()

interact(kmeans_3d_clustering, num_clusters=(2, 6, 1))
# Out:
# interactive(children=(IntSlider(value=4, description='num_clusters', max=6, min=2), Output()), _dom_classes=('…
# <function __main__.kmeans_3d_clustering(num_clusters)>

# %% [markdown]
# ### Elbow Point

# %% [markdown]
# The "elbow point" is a concept often used in the context of K-means clustering to help determine the optimal number of clusters (k) for a given dataset. It is a graphical method that can assist data analysts and machine learning practitioners in finding an appropriate value for k when applying K-means clustering.
#
# The rationale behind the elbow point method is that as you increase the number of clusters (k), the sum of squared distances will generally decrease because data points will be closer to their respective cluster centroids. However, beyond a certain point, subdividing the data into more clusters doesn't provide significant improvements in reducing the sum of squared distances. The elbow point represents that optimal trade-off between the number of clusters and the compactness of each cluster.
#
# It's important to note that the elbow point method is a heuristic and not a foolproof method for determining the ideal k value. In some cases, the elbow point may not be very pronounced, making it challenging to choose the best k. Additionally, the choice of k should also consider domain knowledge and the specific goals of your analysis.

# %%
print('Elbow Method to determine the number of clusters to be formed:')

Elbow_M = KElbowVisualizer(KMeans(), k=(2, 10))
Elbow_M.fit(X_pca)
Elbow_M.show()
# Out:
# Elbow Method to determine the number of clusters to be formed:
# <Axes: title={'center': 'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %% [markdown]
# Similar to classification and regression metrics, we have some [clustering metrics](https://scikit-learn.org/stable/modules/classes.html#clustering-metrics) to evaluate performance.
#
# We wll explore one of them: [adjusted_rand_index (ARI)](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.adjusted_rand_score.html)

# %%
from sklearn.metrics.cluster import adjusted_rand_score
kmeans = KMeans(n_clusters=6, random_state=42)
kmeans_labels = kmeans.fit_predict(X_pca)
# code to compute ARI for our KMeans clusters
adjusted_rand_score(y, kmeans_labels)
# Out:
# 0.4195934235115518

# %% [markdown]
# ### Explainable K-means clustering
#
#
# It refers to an approach that enhances the interpretability and explainability of K-means clustering results. Traditional K-means clustering provides cluster assignments but may not provide intuitive or easily understandable insights into why certain data points belong to a particular cluster. Explainable K-means clustering techniques aim to make the clustering results more transparent and interpretable, often by incorporating additional information or visualization methods. We use the library EXKMC for interpretability. Additional information can be found here - [Explainability](https://www.analyticsvidhya.com/blog/2022/05/adding-explainability-to-clustering/)

# %%
# Perform Explainable K-Means Clustering with interactive widget
def explainable_KMC(num_clusters):
    kmeans = KMeans(n_clusters=num_clusters, random_state=42)# Write Code Here
    kmeans_labels = kmeans.fit_predict(X_pca)# Write Code Here
    tree = Tree(k=num_clusters)
    tree.fit(X_pca, kmeans)
    tree.plot(filename="test", feature_names=activities)
    display(Image(filename='test.gv.png'))
    os.remove("test.gv.png")
    os.remove("test.gv")

interact(explainable_KMC,num_clusters=(2,6,1)) # Fill here
# Out:
# interactive(children=(IntSlider(value=4, description='num_clusters', max=6, min=2), Output()), _dom_classes=('…
# <function __main__.explainable_KMC(num_clusters)>

# %% [markdown]
# # Agglomerative Clustering
#
# It is a hierarchical clustering algorithm used in unsupervised machine learning and data analysis. It is a "bottom-up" or "agglomerative" approach to clustering, where individual data points are initially treated as their own clusters and then progressively merged into larger clusters based on a similarity or distance metric. The result is a tree-like structure called a dendrogram that represents the hierarchical relationships between clusters.
#
# As always, You can find more detailed information about hierarchical clustering, including agglomerative clustering, in the Wikipedia article on "Hierarchical clustering" at the following link: [Hierarchical Clustering Wikipedia](https://en.wikipedia.org/wiki/Hierarchical_clustering). This is the best resource for hierarchical clustering and it is advisable to go through it twice if possible! :)

# %% [markdown]
# ### 2 Dimensional Visualization

# %%
# Perform Agglomerative clustering with interactive widget
def agglomerative_clustering(num_clusters):

    agglomerative = AgglomerativeClustering(n_clusters=num_clusters)
    agglomerative_labels = agglomerative.fit_predict(X_pca)# Write Code here

  # Write the whole plotting part of the code
    plt.figure(figsize=(8, 6))
    plt.scatter(X_pca[:, 0], X_pca[:, 1], c=agglomerative_labels, cmap='viridis', edgecolors='k')

    cluster_centers = list()
    for cluster_label in range(num_clusters):
        cluster_center = np.mean(X_pca[agglomerative_labels == cluster_label], axis=0)
        cluster_centers.append(cluster_center)
    cluster_centers = np.array(cluster_centers)

    plt.scatter(cluster_centers[:, 0], cluster_centers[:, 1], s=200, c='red', marker='X', label='Centroids')
    plt.xlabel('Feature 1 (Standardized)')
    plt.ylabel('Feature 2 (Standardized)')
    plt.title('Agglomerative Clustering')
    plt.legend()
    plt.show()

interact(agglomerative_clustering, num_clusters=(2,6,1)) # Fill here
# Out:
# interactive(children=(IntSlider(value=4, description='num_clusters', max=6, min=2), Output()), _dom_classes=('…
# <function __main__.agglomerative_clustering(num_clusters)>

# %% [markdown]
# ### 3 Dimensional Visualization

# %%
# Perform Agglomerative clustering with interactive widget
def agglomerative_3d_clustering(num_clusters):
    # Write the whole function :)
    agglomerative_3d = AgglomerativeClustering(n_clusters=num_clusters)# Write Code Here
    agglomerative_3d_labels = agglomerative_3d.fit_predict(X_pca)# Write Code Here

    fig = plt.figure(figsize=(10, 8))
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(X_pca[:, 0], X_pca[:, 1], X_pca[:, 2], c=agglomerative_3d_labels, cmap='viridis', edgecolors='k')
    ax.set_xlabel('Feature 1 (Standardized)')
    ax.set_ylabel('Feature 2 (Standardized)')
    ax.set_zlabel('Feature 3 (Standardized)')
    ax.set_title('Agglomerative Clustering (3D)')
    plt.show()

interact(agglomerative_3d_clustering, num_clusters=(2,6,1)) # Fill here
# Out:
# interactive(children=(IntSlider(value=4, description='num_clusters', max=6, min=2), Output()), _dom_classes=('…
# <function __main__.agglomerative_3d_clustering(num_clusters)>

# %%
#You can go through the library of clusteval in order to draw and make dendrograms in your task! Although optional You can perform it if you like :)
# !pip install clusteval -q

# %%
from clusteval import clusteval

# %%
ce = clusteval()

ce.fit(X_pca)
ce.dendrogram(max_d=10)
# Out:
# [clusteval] >INFO> Saving data in memory.
# [clusteval] >INFO> Fit with method=[agglomerative], metric=[euclidean], linkage=[ward]
# [clusteval] >INFO> Evaluate using silhouette.
# [clusteval] >INFO: 100%|██████████| 23/23 [00:53<00:00,  2.35s/it]
# [clusteval] >INFO> Compute dendrogram threshold.
# [clusteval] >INFO> Optimal number clusters detected: [2].
# [clusteval] >INFO> Fin.
# [clusteval] >INFO> Retrieving input data set.
# [clusteval] >INFO> Plotting the dendrogram with optimized settings: metric=euclidean, linkage=ward, max_d=1487.018. Be patient now..
# [clusteval] >INFO> Compute cluster labels.
# {'icoord': [[15.0, 15.0, 25.0, 25.0],
#   [5.0, 5.0, 20.0, 20.0],
#   [35.0, 35.0, 45.0, 45.0],
#   [55.0, 55.0, 65.0, 65.0],
#   [40.0, 40.0, 60.0, 60.0],
#   [75.0, 75.0, 85.0, 85.0],
#   [50.0, 50.0, 80.0, 80.0],
#   [12.5, 12.5, 65.0, 65.0],
#   [125.0, 125.0, 135.0, 135.0],
#   [115.0, 115.0, 130.0, 130.0],
#   [105.0, 105.0, 122.5, 122.5],
#   [95.0, 95.0, 113.75, 113.75],
#   [145.0, 145.0, 155.0, 155.0],
#   [175.0, 175.0, 185.0, 185.0],
#   [165.0, 165.0, 180.0, 180.0],
#   [150.0, 150.0, 172.5, 172.5],
#   [104.375, 104.375, 161.25, 161.25],
#   [38.75, 38.75, 132.8125, 132.8125],
#   [195.0, 195.0, 205.0, 205.0],
#   [215.0, 215.0, 225.0, 225.0],
#   [200.0, 200.0, 220.0, 220.0],
#   [245.0, 245.0, 255.0, 255.0],
#   [235.0, 235.0, 250.0, 250.0],
#   [275.0, 275.0, 285.0, 285.0],
#   [265.0, 265.0, 280.0, 280.0],
#   [295.0, 295.0, 305.0, 305.0],
#   [315.0, 315.0, 325.0, 325.0],
#   [300.0, 300.0, 320.0, 320.0],
#   [272.5, 272.5, 310.0, 310.0],
#   [242.5, 242.5, 291.25, 291.25],
#   [210.0, 210.0, 266.875, 266.875],
#   [335.0, 335.0, 345.0, 345.0],
#   [365.0, 365.0, 375.0, 375.0],
#   [355.0, 355.0, 370.0, 370.0],
#   [340.0, 340.0, 362.5, 362.5],
#   [385.0, 385.0, 395.0, 395.0],
#   [405.0, 405.0, 415.0, 415.0],
#   [390.0, 390.0, 410.0, 410.0],
#   [425.0, 425.0, 435.0, 435.0],
#   [445.0, 445.0, 455.0, 455.0],
#   [430.0, 430.0, 450.0, 450.0],
#   [475.0, 475.0, 485.0, 485.0],
#   [465.0, 465.0, 480.0, 480.0],
#   [505.0, 505.0, 515.0, 515.0],
#   [495.0, 495.0, 510.0, 510.0],
#   [525.0, 525.0, 535.0, 535.0],
#   [545.0, 545.0, 555.0, 555.0],
#   [530.0, 530.0, 550.0, 550.0],
#   [502.5, 502.5, 540.0, 540.0],
#   [472.5, 472.5, 521.25, 521.25],
#   [440.0, 440.0, 496.875, 496.875],
#   [400.0, 400.0, 468.4375, 468.4375],
#   [351.25, 351.25, 434.21875, 434.21875],
#   [238.4375, 238.4375, 392.734375, 392.734375],
#   [565.0, 565.0, 575.0, 575.0],
#   [595.0, 595.0, 605.0, 605.0],
#   [585.0, 585.0, 600.0, 600.0],
#   [615.0, 615.0, 625.0, 625.0],
#   [592.5, 592.5, 620.0, 620.0],
#   [570.0, 570.0, 606.25, 606.25],
#   [645.0, 645.0, 655.0, 655.0],
#   [635.0, 635.0, 650.0, 650.0],
#   [665.0, 665.0, 675.0, 675.0],
#   [685.0, 685.0, 695.0, 695.0],
#   [715.0, 715.0, 725.0, 725.0],
#   [705.0, 705.0, 720.0, 720.0],
#   [690.0, 690.0, 712.5, 712.5],
#   [670.0, 670.0, 701.25, 701.25],
#   [642.5, 642.5, 685.625, 685.625],
#   [588.125, 588.125, 664.0625, 664.0625],
#   [745.0, 745.0, 755.0, 755.0],
#   [735.0, 735.0, 750.0, 750.0],
#   [775.0, 775.0, 785.0, 785.0],
#   [765.0, 765.0, 780.0, 780.0],
#   [742.5, 742.5, 772.5, 772.5],
#   [795.0, 795.0, 805.0, 805.0],
#   [815.0, 815.0, 825.0, 825.0],
#   [800.0, 800.0, 820.0, 820.0],
#   [757.5, 757.5, 810.0, 810.0],
#   [845.0, 845.0, 855.0, 855.0],
#   [835.0, 835.0, 850.0, 850.0],
#   [865.0, 865.0, 875.0, 875.0],
#   [885.0, 885.0, 895.0, 895.0],
#   [870.0, 870.0, 890.0, 890.0],
#   [842.5, 842.5, 880.0, 880.0],
#   [905.0, 905.0, 915.0, 915.0],
#   [925.0, 925.0, 935.0, 935.0],
#   [965.0, 965.0, 975.0, 975.0],
#   [955.0, 955.0, 970.0, 970.0],
#   [945.0, 945.0, 962.5, 962.5],
#   [930.0, 930.0, 953.75, 953.75],
#   [910.0, 910.0, 941.875, 941.875],
#   [861.25, 861.25, 925.9375, 925.9375],
#   [783.75, 783.75, 893.59375, 893.59375],
#   [1005.0, 1005.0, 1015.0, 1015.0],
#   [995.0, 995.0, 1010.0, 1010.0],
#   [1035.0, 1035.0, 1045.0, 1045.0],
#   [1025.0, 1025.0, 1040.0, 1040.0],
#   [1002.5, 1002.5, 1032.5, 1032.5],
#   [985.0, 985.0, 1017.5, 1017.5],
#   [1055.0, 1055.0, 1065.0, 1065.0],
#   [1075.0, 1075.0, 1085.0, 1085.0],
#   [1105.0, 1105.0, 1115.0, 1115.0],
#   [1095.0, 1095.0, 1110.0, 1110.0],
#   [1080.0, 1080.0, 1102.5, 1102.5],
#   [1060.0, 1060.0, 1091.25, 1091.25],
#   [1001.25, 1001.25, 1075.625, 1075.625],
#   [838.671875, 838.671875, 1038.4375, 1038.4375],
#   [626.09375, 626.09375, 938.5546875, 938.5546875],
#   [315.5859375, 315.5859375, 782.32421875, 782.32421875],
#   [85.78125, 85.78125, 548.955078125, 548.955078125],
#   [1125.0, 1125.0, 1135.0, 1135.0],
#   [1165.0, 1165.0, 1175.0, 1175.0],
#   [1155.0, 1155.0, 1170.0, 1170.0],
#   [1145.0, 1145.0, 1162.5, 1162.5],
#   [1130.0, 1130.0, 1153.75, 1153.75],
#   [1205.0, 1205.0, 1215.0, 1215.0],
#   [1195.0, 1195.0, 1210.0, 1210.0],
#   [1185.0, 1185.0, 1202.5, 1202.5],
#   [1235.0, 1235.0, 1245.0, 1245.0],
#   [1225.0, 1225.0, 1240.0, 1240.0],
#   [1255.0, 1255.0, 1265.0, 1265.0],
#   [1275.0, 1275.0, 1285.0, 1285.0],
#   [1260.0, 1260.0, 1280.0, 1280.0],
#   [1232.5, 1232.5, 1270.0, 1270.0],
#   [1193.75, 1193.75, 1251.25, 1251.25],
#   [1141.875, 1141.875, 1222.5, 1222.5],
#   [1295.0, 1295.0, 1305.0, 1305.0],
#   [1325.0, 1325.0, 1335.0, 1335.0],
#   [1315.0, 1315.0, 1330.0, 1330.0],
#   [1300.0, 1300.0, 1322.5, 1322.5],
#   [1345.0, 1345.0, 1355.0, 1355.0],
#   [1375.0, 1375.0, 1385.0, 1385.0],
#   [1365.0, 1365.0, 1380.0, 1380.0],
#   [1350.0, 1350.0, 1372.5, 1372.5],
#   [1395.0, 1395.0, 1405.0, 1405.0],
#   [1415.0, 1415.0, 1425.0, 1425.0],
#   [1400.0, 1400.0, 1420.0, 1420.0],
#   [1435.0, 1435.0, 1445.0, 1445.0],
#   [1455.0, 1455.0, 1465.0, 1465.0],
#   [1440.0, 1440.0, 1460.0, 1460.0],
#   [1410.0, 1410.0, 1450.0, 1450.0],
#   [1361.25, 1361.25, 1430.0, 1430.0],
#   [1311.25, 1311.25, 1395.625, 1395.625],
#   [1475.0, 1475.0, 1485.0, 1485.0],
#   [1495.0, 1495.0, 1505.0, 1505.0],
#   [1515.0, 1515.0, 1525.0, 1525.0],
#   [1535.0, 1535.0, 1545.0, 1545.0],
#   [1565.0, 1565.0, 1575.0, 1575.0],
#   [1555.0, 1555.0, 1570.0, 1570.0],
#   [1540.0, 1540.0, 1562.5, 1562.5],
#   [1520.0, 1520.0, 1551.25, 1551.25],
#   [1500.0, 1500.0, 1535.625, 1535.625],
#   [1480.0, 1480.0, 1517.8125, 1517.8125],
#   [1595.0, 1595.0, 1605.0, 1605.0],
#   [1585.0, 1585.0, 1600.0, 1600.0],
#   [1615.0, 1615.0, 1625.0, 1625.0],
#   [1655.0, 1655.0, 1665.0, 1665.0],
#   [1645.0, 1645.0, 1660.0, 1660.0],
#   [1635.0, 1635.0, 1652.5, 1652.5],
#   [1620.0, 1620.0, 1643.75, 1643.75],
#   [1675.0, 1675.0, 1685.0, 1685.0],
#   [1705.0, 1705.0, 1715.0, 1715.0],
#   [1695.0, 1695.0, 1710.0, 1710.0],
#   [1680.0, 1680.0, 1702.5, 1702.5],
#   [1631.875, 1631.875, 1691.25, 1691.25],
#   [1592.5, 1592.5, 1661.5625, 1661.5625],
#   [1498.90625, 1498.90625, 1627.03125, 1627.03125],
#   [1735.0, 1735.0, 1745.0, 1745.0],
#   [1725.0, 1725.0, 1740.0, 1740.0],
#   [1765.0, 1765.0, 1775.0, 1775.0],
#   [1755.0, 1755.0, 1770.0, 1770.0],
#   [1795.0, 1795.0, 1805.0, 1805.0],
#   [1785.0, 1785.0, 1800.0, 1800.0],
#   [1835.0, 1835.0, 1845.0, 1845.0],
#   [1825.0, 1825.0, 1840.0, 1840.0],
#   [1815.0, 1815.0, 1832.5, 1832.5],
#   [1792.5, 1792.5, 1823.75, 1823.75],
#   [1855.0, 1855.0, 1865.0, 1865.0],
#   [1885.0, 1885.0, 1895.0, 1895.0],
#   [1875.0, 1875.0, 1890.0, 1890.0],
#   [1860.0, 1860.0, 1882.5, 1882.5],
#   [1808.125, 1808.125, 1871.25, 1871.25],
#   [1762.5, 1762.5, 1839.6875, 1839.6875],
#   [1732.5, 1732.5, 1801.09375, 1801.09375],
#   [1562.96875, 1562.96875, 1766.796875, 1766.796875],
#   [1353.4375, 1353.4375, 1664.8828125, 1664.8828125],
#   [1182.1875, 1182.1875, 1509.16015625, 1509.16015625],
#   [1915.0, 1915.0, 1925.0, 1925.0],
#   [1935.0, 1935.0, 1945.0, 1945.0],
#   [1955.0, 1955.0, 1965.0, 1965.0],
#   [1940.0, 1940.0, 1960.0, 1960.0],
#   [1920.0, 1920.0, 1950.0, 1950.0],
#   [1905.0, 1905.0, 1935.0, 1935.0],
#   [1975.0, 1975.0, 1985.0, 1985.0],
#   [2005.0, 2005.0, 2015.0, 2015.0],
#   [1995.0, 1995.0, 2010.0, 2010.0],
#   [1980.0, 1980.0, 2002.5, 2002.5],
#   [2025.0, 2025.0, 2035.0, 2035.0],
#   [2045.0, 2045.0, 2055.0, 2055.0],
#   [2085.0, 2085.0, 2095.0, 2095.0],
#   [2075.0, 2075.0, 2090.0, 2090.0],
#   [2065.0, 2065.0, 2082.5, 2082.5],
#   [2050.0, 2050.0, 2073.75, 2073.75],
#   [2030.0, 2030.0, 2061.875, 2061.875],
#   [1991.25, 1991.25, 2045.9375, 2045.9375],
#   [1920.0, 1920.0, 2018.59375, 2018.59375],
#   [2125.0, 2125.0, 2135.0, 2135.0],
#   [2115.0, 2115.0, 2130.0, 2130.0],
#   [2105.0, 2105.0, 2122.5, 2122.5],
#   [2155.0, 2155.0, 2165.0, 2165.0],
#   [2145.0, 2145.0, 2160.0, 2160.0],
#   [2175.0, 2175.0, 2185.0, 2185.0],
#   [2205.0, 2205.0, 2215.0, 2215.0],
#   [2195.0, 2195.0, 2210.0, 2210.0],
#   [2225.0, 2225.0, 2235.0, 2235.0],
#   [2245.0, 2245.0, 2255.0, 2255.0],
#   [2230.0, 2230.0, 2250.0, 2250.0],
#   [2202.5, 2202.5, 2240.0, 2240.0],
#   [2180.0, 2180.0, 2221.25, 2221.25],
#   [2152.5, 2152.5, 2200.625, 2200.625],
#   [2113.75, 2113.75, 2176.5625, 2176.5625],
#   [2275.0, 2275.0, 2285.0, 2285.0],
#   [2265.0, 2265.0, 2280.0, 2280.0],
#   [2305.0, 2305.0, 2315.0, 2315.0],
#   [2295.0, 2295.0, 2310.0, 2310.0],
#   [2325.0, 2325.0, 2335.0, 2335.0],
#   [2355.0, 2355.0, 2365.0, 2365.0],
#   [2345.0, 2345.0, 2360.0, 2360.0],
#   [2330.0, 2330.0, 2352.5, 2352.5],
#   [2375.0, 2375.0, 2385.0, 2385.0],
#   [2405.0, 2405.0, 2415.0, 2415.0],
#   [2395.0, 2395.0, 2410.0, 2410.0],
#   [2380.0, 2380.0, 2402.5, 2402.5],
#   [2341.25, 2341.25, 2391.25, 2391.25],
#   [2302.5, 2302.5, 2366.25, 2366.25],
#   [2272.5, 2272.5, 2334.375, 2334.375],
#   [2435.0, 2435.0, 2445.0, 2445.0],
#   [2425.0, 2425.0, 2440.0, 2440.0],
#   [2455.0, 2455.0, 2465.0, 2465.0],
#   [2485.0, 2485.0, 2495.0, 2495.0],
#   [2475.0, 2475.0, 2490.0, 2490.0],
#   [2460.0, 2460.0, 2482.5, 2482.5],
#   [2515.0, 2515.0, 2525.0, 2525.0],
#   [2535.0, 2535.0, 2545.0, 2545.0],
#   [2520.0, 2520.0, 2540.0, 2540.0],
#   [2505.0, 2505.0, 2530.0, 2530.0],
#   [2471.25, 2471.25, 2517.5, 2517.5],
#   [2432.5, 2432.5, 2494.375, 2494.375],
#   [2303.4375, 2303.4375, 2463.4375, 2463.4375],
#   [2145.15625, 2145.15625, 2383.4375, 2383.4375],
#   [1969.296875, 1969.296875, 2264.296875, 2264.296875],
#   [1345.673828125, 1345.673828125, 2116.796875, 2116.796875],
#   [317.3681640625, 317.3681640625, 1731.2353515625, 1731.2353515625],
#   [2555.0, 2555.0, 2565.0, 2565.0],
#   [2575.0, 2575.0, 2585.0, 2585.0],
#   [2595.0, 2595.0, 2605.0, 2605.0],
#   [2625.0, 2625.0, 2635.0, 2635.0],
#   [2615.0, 2615.0, 2630.0, 2630.0],
#   [2600.0, 2600.0, 2622.5, 2622.5],
#   [2580.0, 2580.0, 2611.25, 2611.25],
#   [2560.0, 2560.0, 2595.625, 2595.625],
#   [2655.0, 2655.0, 2665.0, 2665.0],
#   [2645.0, 2645.0, 2660.0, 2660.0],
#   [2675.0, 2675.0, 2685.0, 2685.0],
#   [2705.0, 2705.0, 2715.0, 2715.0],
#   [2695.0, 2695.0, 2710.0, 2710.0],
#   [2725.0, 2725.0, 2735.0, 2735.0],
#   [2702.5, 2702.5, 2730.0, 2730.0],
#   [2680.0, 2680.0, 2716.25, 2716.25],
#   [2652.5, 2652.5, 2698.125, 2698.125],
#   [2745.0, 2745.0, 2755.0, 2755.0],
#   [2775.0, 2775.0, 2785.0, 2785.0],
#   [2765.0, 2765.0, 2780.0, 2780.0],
#   [2750.0, 2750.0, 2772.5, 2772.5],
#   [2795.0, 2795.0, 2805.0, 2805.0],
#   [2825.0, 2825.0, 2835.0, 2835.0],
#   [2815.0, 2815.0, 2830.0, 2830.0],
#   [2800.0, 2800.0, 2822.5, 2822.5],
#   [2761.25, 2761.25, 2811.25, 2811.25],
#   [2675.3125, 2675.3125, 2786.25, 2786.25],
#   [2845.0, 2845.0, 2855.0, 2855.0],
#   [2875.0, 2875.0, 2885.0, 2885.0],
#   [2865.0, 2865.0, 2880.0, 2880.0],
#   [2850.0, 2850.0, 2872.5, 2872.5],
#   [2915.0, 2915.0, 2925.0, 2925.0],
#   [2905.0, 2905.0, 2920.0, 2920.0],
#   [2935.0, 2935.0, 2945.0, 2945.0],
#   [2955.0, 2955.0, 2965.0, 2965.0],
#   [2940.0, 2940.0, 2960.0, 2960.0],
#   [2912.5, 2912.5, 2950.0, 2950.0],
#   [2895.0, 2895.0, 2931.25, 2931.25],
#   [2861.25, 2861.25, 2913.125, 2913.125],
#   [2975.0, 2975.0, 2985.0, 2985.0],
#   [3005.0, 3005.0, 3015.0, 3015.0],
#   [2995.0, 2995.0, 3010.0, 3010.0],
#   [2980.0, 2980.0, 3002.5, 3002.5],
#   [3035.0, 3035.0, 3045.0, 3045.0],
#   [3025.0, 3025.0, 3040.0, 3040.0],
#   [3065.0, 3065.0, 3075.0, 3075.0],
#   [3055.0, 3055.0, 3070.0, 3070.0],
#   [3095.0, 3095.0, 3105.0, 3105.0],
#   [3085.0, 3085.0, 3100.0, 3100.0],
#   [3062.5, 3062.5, 3092.5, 3092.5],
#   [3032.5, 3032.5, 3077.5, 3077.5],
#   [2991.25, 2991.25, 3055.0, 3055.0],
#   [2887.1875, 2887.1875, 3023.125, 3023.125],
#   [2730.78125, 2730.78125, 2955.15625, 2955.15625],
#   [3115.0, 3115.0, 3125.0, 3125.0],
#   [3145.0, 3145.0, 3155.0, 3155.0],
#   [3165.0, 3165.0, 3175.0, 3175.0],
#   [3150.0, 3150.0, 3170.0, 3170.0],
#   [3135.0, 3135.0, 3160.0, 3160.0],
#   [3120.0, 3120.0, 3147.5, 3147.5],
#   [3185.0, 3185.0, 3195.0, 3195.0],
#   [3215.0, 3215.0, 3225.0, 3225.0],
#   [3245.0, 3245.0, 3255.0, 3255.0],
#   [3235.0, 3235.0, 3250.0, 3250.0],
#   [3220.0, 3220.0, 3242.5, 3242.5],
#   [3205.0, 3205.0, 3231.25, 3231.25],
#   [3190.0, 3190.0, 3218.125, 3218.125],
#   [3265.0, 3265.0, 3275.0, 3275.0],
#   [3285.0, 3285.0, 3295.0, 3295.0],
#   [3305.0, 3305.0, 3315.0, 3315.0],
#   [3290.0, 3290.0, 3310.0, 3310.0],
#   [3270.0, 3270.0, 3300.0, 3300.0],
#   [3204.0625, 3204.0625, 3285.0, 3285.0],
#   [3133.75, 3133.75, 3244.53125, 3244.53125],
#   [3325.0, 3325.0, 3335.0, 3335.0],
#   [3345.0, 3345.0, 3355.0, 3355.0],
#   [3365.0, 3365.0, 3375.0, 3375.0],
#   [3350.0, 3350.0, 3370.0, 3370.0],
#   [3330.0, 3330.0, 3360.0, 3360.0],
#   [3385.0, 3385.0, 3395.0, 3395.0],
#   [3405.0, 3405.0, 3415.0, 3415.0],
#   [3425.0, 3425.0, 3435.0, 3435.0],
#   [3410.0, 3410.0, 3430.0, 3430.0],
#   [3390.0, 3390.0, 3420.0, 3420.0],
#   [3345.0, 3345.0, 3405.0, 3405.0],
#   [3445.0, 3445.0, 3455.0, 3455.0],
#   [3485.0, 3485.0, 3495.0, 3495.0],
#   [3475.0, 3475.0, 3490.0, 3490.0],
#   [3465.0, 3465.0, 3482.5, 3482.5],
#   [3450.0, 3450.0, 3473.75, 3473.75],
#   [3515.0, 3515.0, 3525.0, 3525.0],
#   [3505.0, 3505.0, 3520.0, 3520.0],
#   [3535.0, 3535.0, 3545.0, 3545.0],
#   [3512.5, 3512.5, 3540.0, 3540.0],
#   [3461.875, 3461.875, 3526.25, 3526.25],
#   [3375.0, 3375.0, 3494.0625, 3494.0625],
#   [3189.140625, 3189.140625, 3434.53125, 3434.53125],
#   [2842.96875, 2842.96875, 3311.8359375, 3311.8359375],
#   [2577.8125, 2577.8125, 3077.40234375, 3077.40234375],
#   [3565.0, 3565.0, 3575.0, 3575.0],
#   [3585.0, 3585.0, 3595.0, 3595.0],
#   [3570.0, 3570.0, 3590.0, 3590.0],
#   [3555.0, 3555.0, 3580.0, 3580.0],
#   [3615.0, 3615.0, 3625.0, 3625.0],
#   [3605.0, 3605.0, 3620.0, 3620.0],
#   [3567.5, 3567.5, 3612.5, 3612.5],
#   [3635.0, 3635.0, 3645.0, 3645.0],
#   [3665.0, 3665.0, 3675.0, 3675.0],
#   [3655.0, 3655.0, 3670.0, 3670.0],
#   [3640.0, 3640.0, 3662.5, 3662.5],
#   [3685.0, 3685.0, 3695.0, 3695.0],
#   [3705.0, 3705.0, 3715.0, 3715.0],
#   [3690.0, 3690.0, 3710.0, 3710.0],
#   [3725.0, 3725.0, 3735.0, 3735.0],
#   [3745.0, 3745.0, 3755.0, 3755.0],
#   [3730.0, 3730.0, 3750.0, 3750.0],
#   [3700.0, 3700.0, 3740.0, 3740.0],
#   [3651.25, 3651.25, 3720.0, 3720.0],
#   [3590.0, 3590.0, 3685.625, 3685.625],
#   [3775.0, 3775.0, 3785.0, 3785.0],
#   [3765.0, 3765.0, 3780.0, 3780.0],
#   [3795.0, 3795.0, 3805.0, 3805.0],
#   [3825.0, 3825.0, 3835.0, 3835.0],
#   [3815.0, 3815.0, 3830.0, 3830.0],
#   [3800.0, 3800.0, 3822.5, 3822.5],
#   [3772.5, 3772.5, 3811.25, 3811.25],
#   [3845.0, 3845.0, 3855.0, 3855.0],
#   [3875.0, 3875.0, 3885.0, 3885.0],
#   [3865.0, 3865.0, 3880.0, 3880.0],
#   [3850.0, 3850.0, 3872.5, 3872.5],
#   [3895.0, 3895.0, 3905.0, 3905.0],
#   [3915.0, 3915.0, 3925.0, 3925.0],
#   [3900.0, 3900.0, 3920.0, 3920.0],
#   [3861.25, 3861.25, 3910.0, 3910.0],
#   [3791.875, 3791.875, 3885.625, 3885.625],
#   [3945.0, 3945.0, 3955.0, 3955.0],
#   [3935.0, 3935.0, 3950.0, 3950.0],
#   [3975.0, 3975.0, 3985.0, 3985.0],
#   [4005.0, 4005.0, 4015.0, 4015.0],
#   [3995.0, 3995.0, 4010.0, 4010.0],
#   [3980.0, 3980.0, 4002.5, 4002.5],
#   [3965.0, 3965.0, 3991.25, 3991.25],
#   [3942.5, 3942.5, 3978.125, 3978.125],
#   [4025.0, 4025.0, 4035.0, 4035.0],
#   [4045.0, 4045.0, 4055.0, 4055.0],
#   [4065.0, 4065.0, 4075.0, 4075.0],
#   [4050.0, 4050.0, 4070.0, 4070.0],
#   [4030.0, 4030.0, 4060.0, 4060.0],
#   [4095.0, 4095.0, 4105.0, 4105.0],
#   [4085.0, 4085.0, 4100.0, 4100.0],
#   [4045.0, 4045.0, 4092.5, 4092.5],
#   [4115.0, 4115.0, 4125.0, 4125.0],
#   [4145.0, 4145.0, 4155.0, 4155.0],
#   [4135.0, 4135.0, 4150.0, 4150.0],
#   [4120.0, 4120.0, 4142.5, 4142.5],
#   [4175.0, 4175.0, 4185.0, 4185.0],
#   [4165.0, 4165.0, 4180.0, 4180.0],
#   [4215.0, 4215.0, 4225.0, 4225.0],
#   [4205.0, 4205.0, 4220.0, 4220.0],
#   [4195.0, 4195.0, 4212.5, 4212.5],
#   [4172.5, 4172.5, 4203.75, 4203.75],
#   [4131.25, 4131.25, 4188.125, 4188.125],
#   [4068.75, 4068.75, 4159.6875, 4159.6875],
#   [3960.3125, 3960.3125, 4114.21875, 4114.21875],
#   [3838.75, 3838.75, 4037.265625, 4037.265625],
#   [3637.8125, 3637.8125, 3938.0078125, 3938.0078125],
#   [2827.607421875, 2827.607421875, 3787.91015625, 3787.91015625],
#   [1024.3017578125, 1024.3017578125, 3307.7587890625, 3307.7587890625],
#   [4235.0, 4235.0, 4245.0, 4245.0],
#   [4265.0, 4265.0, 4275.0, 4275.0],
#   [4255.0, 4255.0, 4270.0, 4270.0],
#   [4240.0, 4240.0, 4262.5, 4262.5],
#   [4285.0, 4285.0, 4295.0, 4295.0],
#   [4305.0, 4305.0, 4315.0, 4315.0],
#   [4290.0, 4290.0, 4310.0, 4310.0],
#   [4345.0, 4345.0, 4355.0, 4355.0],
#   [4335.0, 4335.0, 4350.0, 4350.0],
#   [4325.0, 4325.0, 4342.5, 4342.5],
#   [4300.0, 4300.0, 4333.75, 4333.75],
#   [4385.0, 4385.0, 4395.0, 4395.0],
#   [4375.0, 4375.0, 4390.0, 4390.0],
#   [4365.0, 4365.0, 4382.5, 4382.5],
#   [4316.875, 4316.875, 4373.75, 4373.75],
#   [4251.25, 4251.25, 4345.3125, 4345.3125],
#   [4435.0, 4435.0, 4445.0, 4445.0],
#   [4425.0, 4425.0, 4440.0, 4440.0],
#   [4415.0, 4415.0, 4432.5, 4432.5],
#   [4405.0, 4405.0, 4423.75, 4423.75],
#   [4465.0, 4465.0, 4475.0, 4475.0],
#   [4455.0, 4455.0, 4470.0, 4470.0],
#   [4505.0, 4505.0, 4515.0, 4515.0],
#   [4495.0, 4495.0, 4510.0, 4510.0],
#   [4485.0, 4485.0, 4502.5, 4502.5],
#   [4462.5, 4462.5, 4493.75, 4493.75],
#   [4414.375, 4414.375, 4478.125, 4478.125],
#   [4535.0, 4535.0, 4545.0, 4545.0],
#   [4555.0, 4555.0, 4565.0, 4565.0],
#   [4540.0, 4540.0, 4560.0, 4560.0],
#   [4525.0, 4525.0, 4550.0, 4550.0],
#   [4575.0, 4575.0, 4585.0, 4585.0],
#   [4595.0, 4595.0, 4605.0, 4605.0],
#   [4615.0, 4615.0, 4625.0, 4625.0],
#   [4600.0, 4600.0, 4620.0, 4620.0],
#   [4580.0, 4580.0, 4610.0, 4610.0],
#   [4537.5, 4537.5, 4595.0, 4595.0],
#   [4446.25, 4446.25, 4566.25, 4566.25],
#   [4298.28125, 4298.28125, 4506.25, 4506.25],
#   [4635.0, 4635.0, 4645.0, 4645.0],
#   [4665.0, 4665.0, 4675.0, 4675.0],
#   [4655.0, 4655.0, 4670.0, 4670.0],
#   [4640.0, 4640.0, 4662.5, 4662.5],
#   [4685.0, 4685.0, 4695.0, 4695.0],
#   [4705.0, 4705.0, 4715.0, 4715.0],
#   [4690.0, 4690.0, 4710.0, 4710.0],
#   [4651.25, 4651.25, 4700.0, 4700.0],
#   [4725.0, 4725.0, 4735.0, 4735.0],
#   [4745.0, 4745.0, 4755.0, 4755.0],
#   [4730.0, 4730.0, 4750.0, 4750.0],
#   [4775.0, 4775.0, 4785.0, 4785.0],
#   [4765.0, 4765.0, 4780.0, 4780.0],
#   [4795.0, 4795.0, 4805.0, 4805.0],
#   [4772.5, 4772.5, 4800.0, 4800.0],
#   [4740.0, 4740.0, 4786.25, 4786.25],
#   [4835.0, 4835.0, 4845.0, 4845.0],
#   [4825.0, 4825.0, 4840.0, 4840.0],
#   [4815.0, 4815.0, 4832.5, 4832.5],
#   [4865.0, 4865.0, 4875.0, 4875.0],
#   [4855.0, 4855.0, 4870.0, 4870.0],
#   [4885.0, 4885.0, 4895.0, 4895.0],
#   [4905.0, 4905.0, 4915.0, 4915.0],
#   [4890.0, 4890.0, 4910.0, 4910.0],
#   [4862.5, 4862.5, 4900.0, 4900.0],
#   [4823.75, 4823.75, 4881.25, 4881.25],
#   [4763.125, 4763.125, 4852.5, 4852.5],
#   [4925.0, 4925.0, 4935.0, 4935.0],
#   [4955.0, 4955.0, 4965.0, 4965.0],
#   [4945.0, 4945.0, 4960.0, 4960.0],
#   [4985.0, 4985.0, 4995.0, 4995.0],
#   [4975.0, 4975.0, 4990.0, 4990.0],
#   [4952.5, 4952.5, 4982.5, 4982.5],
#   [4930.0, 4930.0, 4967.5, 4967.5],
#   [5005.0, 5005.0, 5015.0, 5015.0],
#   [5035.0, 5035.0, 5045.0, 5045.0],
#   [5025.0, 5025.0, 5040.0, 5040.0],
#   [5010.0, 5010.0, 5032.5, 5032.5],
#   [5065.0, 5065.0, 5075.0, 5075.0],
#   [5055.0, 5055.0, 5070.0, 5070.0],
#   [5095.0, 5095.0, 5105.0, 5105.0],
#   [5085.0, 5085.0, 5100.0, 5100.0],
#   [5125.0, 5125.0, 5135.0, 5135.0],
#   [5115.0, 5115.0, 5130.0, 5130.0],
#   [5092.5, 5092.5, 5122.5, 5122.5],
#   [5062.5, 5062.5, 5107.5, 5107.5],
#   [5021.25, 5021.25, 5085.0, 5085.0],
#   [4948.75, 4948.75, 5053.125, 5053.125],
#   [4807.8125, 4807.8125, 5000.9375, 5000.9375],
#   [5145.0, 5145.0, 5155.0, 5155.0],
#   [5175.0, 5175.0, 5185.0, 5185.0],
#   [5165.0, 5165.0, 5180.0, 5180.0],
#   [5195.0, 5195.0, 5205.0, 5205.0],
#   [5225.0, 5225.0, 5235.0, 5235.0],
#   [5215.0, 5215.0, 5230.0, 5230.0],
#   [5200.0, 5200.0, 5222.5, 5222.5],
#   [5172.5, 5172.5, 5211.25, 5211.25],
#   [5150.0, 5150.0, 5191.875, 5191.875],
#   [5245.0, 5245.0, 5255.0, 5255.0],
#   [5265.0, 5265.0, 5275.0, 5275.0],
#   [5250.0, 5250.0, 5270.0, 5270.0],
#   [5285.0, 5285.0, 5295.0, 5295.0],
#   [5305.0, 5305.0, 5315.0, 5315.0],
#   [5355.0, 5355.0, 5365.0, 5365.0],
#   [5345.0, 5345.0, 5360.0, 5360.0],
#   [5335.0, 5335.0, 5352.5, 5352.5],
#   [5325.0, 5325.0, 5343.75, 5343.75],
#   [5310.0, 5310.0, 5334.375, 5334.375],
#   [5290.0, 5290.0, 5322.1875, 5322.1875],
#   [5260.0, 5260.0, 5306.09375, 5306.09375],
#   [5170.9375, 5170.9375, 5283.046875, 5283.046875],
#   [4904.375, 4904.375, 5226.9921875, 5226.9921875],
#   [4675.625, 4675.625, 5065.68359375, 5065.68359375],
#   [4402.265625, 4402.265625, 4870.654296875, 4870.654296875],
#   [5375.0, 5375.0, 5385.0, 5385.0],
#   [5405.0, 5405.0, 5415.0, 5415.0],
#   [5435.0, 5435.0, 5445.0, 5445.0],
#   [5425.0, 5425.0, 5440.0, 5440.0],
#   [5475.0, 5475.0, 5485.0, 5485.0],
#   [5465.0, 5465.0, 5480.0, 5480.0],
#   [5455.0, 5455.0, 5472.5, 5472.5],
#   [5432.5, 5432.5, 5463.75, 5463.75],
#   [5410.0, 5410.0, 5448.125, 5448.125],
#   [5395.0, 5395.0, 5429.0625, 5429.0625],
#   [5525.0, 5525.0, 5535.0, 5535.0],
#   [5515.0, 5515.0, 5530.0, 5530.0],
#   [5505.0, 5505.0, 5522.5, 5522.5],
#   [5495.0, 5495.0, 5513.75, 5513.75],
#   [5555.0, 5555.0, 5565.0, 5565.0],
#   [5545.0, 5545.0, 5560.0, 5560.0],
#   [5575.0, 5575.0, 5585.0, 5585.0],
#   [5595.0, 5595.0, 5605.0, 5605.0],
#   [5625.0, 5625.0, 5635.0, 5635.0],
#   [5615.0, 5615.0, 5630.0, 5630.0],
#   [5600.0, 5600.0, 5622.5, 5622.5],
#   [5580.0, 5580.0, 5611.25, 5611.25],
#   [5552.5, 5552.5, 5595.625, 5595.625],
#   [5504.375, 5504.375, 5574.0625, 5574.0625],
#   [5412.03125, 5412.03125, 5539.21875, 5539.21875],
#   [5380.0, 5380.0, 5475.625, 5475.625],
#   [5645.0, 5645.0, 5655.0, 5655.0],
#   [5675.0, 5675.0, 5685.0, 5685.0],
#   [5665.0, 5665.0, 5680.0, 5680.0],
#   [5650.0, 5650.0, 5672.5, 5672.5],
#   [5695.0, 5695.0, 5705.0, 5705.0],
#   [5715.0, 5715.0, 5725.0, 5725.0],
#   [5700.0, 5700.0, 5720.0, 5720.0],
#   [5735.0, 5735.0, 5745.0, 5745.0],
#   [5765.0, 5765.0, 5775.0, 5775.0],
#   [5755.0, 5755.0, 5770.0, 5770.0],
#   [5740.0, 5740.0, 5762.5, 5762.5],
#   [5710.0, 5710.0, 5751.25, 5751.25],
#   [5661.25, 5661.25, 5730.625, 5730.625],
#   [5785.0, 5785.0, 5795.0, 5795.0],
#   [5805.0, 5805.0, 5815.0, 5815.0],
#   [5790.0, 5790.0, 5810.0, 5810.0],
#   [5835.0, 5835.0, 5845.0, 5845.0],
#   [5825.0, 5825.0, 5840.0, 5840.0],
#   [5855.0, 5855.0, 5865.0, 5865.0],
#   [5832.5, 5832.5, 5860.0, 5860.0],
#   [5800.0, 5800.0, 5846.25, 5846.25],
#   [5885.0, 5885.0, 5895.0, 5895.0],
#   [5875.0, 5875.0, 5890.0, 5890.0],
#   [5905.0, 5905.0, 5915.0, 5915.0],
#   [5935.0, 5935.0, 5945.0, 5945.0],
#   [5925.0, 5925.0, 5940.0, 5940.0],
#   [5910.0, 5910.0, 5932.5, 5932.5],
#   [5882.5, 5882.5, 5921.25, 5921.25],
#   [5955.0, 5955.0, 5965.0, 5965.0],
#   [5975.0, 5975.0, 5985.0, 5985.0],
#   [5960.0, 5960.0, 5980.0, 5980.0],
#   [5995.0, 5995.0, 6005.0, 6005.0],
#   [6025.0, 6025.0, 6035.0, 6035.0],
#   [6015.0, 6015.0, 6030.0, 6030.0],
#   [6000.0, 6000.0, 6022.5, 6022.5],
#   [5970.0, 5970.0, 6011.25, 6011.25],
#   [5901.875, 5901.875, 5990.625, 5990.625],
#   [5823.125, 5823.125, 5946.25, 5946.25],
#   [5695.9375, 5695.9375, 5884.6875, 5884.6875],
#   [5427.8125, 5427.8125, 5790.3125, 5790.3125],
#   [6055.0, 6055.0, 6065.0, 6065.0],
#   [6045.0, 6045.0, 6060.0, 6060.0],
#   [6075.0, 6075.0, 6085.0, 6085.0],
#   [6052.5, 6052.5, 6080.0, 6080.0],
#   [6095.0, 6095.0, 6105.0, 6105.0],
#   [6115.0, 6115.0, 6125.0, 6125.0],
#   [6135.0, 6135.0, 6145.0, 6145.0],
#   [6155.0, 6155.0, 6165.0, 6165.0],
#   [6140.0, 6140.0, 6160.0, 6160.0],
#   [6120.0, 6120.0, 6150.0, 6150.0],
#   [6100.0, 6100.0, 6135.0, 6135.0],
#   [6066.25, 6066.25, 6117.5, 6117.5],
#   [6175.0, 6175.0, 6185.0, 6185.0],
#   [6195.0, 6195.0, 6205.0, 6205.0],
#   [6215.0, 6215.0, 6225.0, 6225.0],
#   [6235.0, 6235.0, 6245.0, 6245.0],
#   [6220.0, 6220.0, 6240.0, 6240.0],
#   [6200.0, 6200.0, 6230.0, 6230.0],
#   [6180.0, 6180.0, 6215.0, 6215.0],
#   [6255.0, 6255.0, 6265.0, 6265.0],
#   [6285.0, 6285.0, 6295.0, 6295.0],
#   [6275.0, 6275.0, 6290.0, 6290.0],
#   [6260.0, 6260.0, 6282.5, 6282.5],
#   [6305.0, 6305.0, 6315.0, 6315.0],
#   [6325.0, 6325.0, 6335.0, 6335.0],
#   [6310.0, 6310.0, 6330.0, 6330.0],
#   [6345.0, 6345.0, 6355.0, 6355.0],
#   [6365.0, 6365.0, 6375.0, 6375.0],
#   [6350.0, 6350.0, 6370.0, 6370.0],
#   [6320.0, 6320.0, 6360.0, 6360.0],
#   [6271.25, 6271.25, 6340.0, 6340.0],
#   [6197.5, 6197.5, 6305.625, 6305.625],
#   [6385.0, 6385.0, 6395.0, 6395.0],
#   [6405.0, 6405.0, 6415.0, 6415.0],
#   [6390.0, 6390.0, 6410.0, 6410.0],
#   [6445.0, 6445.0, 6455.0, 6455.0],
#   [6435.0, 6435.0, 6450.0, 6450.0],
#   [6425.0, 6425.0, 6442.5, 6442.5],
#   [6465.0, 6465.0, 6475.0, 6475.0],
#   [6485.0, 6485.0, 6495.0, 6495.0],
#   [6470.0, 6470.0, 6490.0, 6490.0],
#   [6505.0, 6505.0, 6515.0, 6515.0],
#   [6480.0, 6480.0, 6510.0, 6510.0],
#   [6433.75, 6433.75, 6495.0, 6495.0],
#   [6400.0, 6400.0, 6464.375, 6464.375],
#   [6251.5625, 6251.5625, 6432.1875, 6432.1875],
#   [6091.875, 6091.875, 6341.875, 6341.875],
#   [6535.0, 6535.0, 6545.0, 6545.0],
#   [6525.0, 6525.0, 6540.0, 6540.0],
#   [6555.0, 6555.0, 6565.0, 6565.0],
#   [6585.0, 6585.0, 6595.0, 6595.0],
#   [6575.0, 6575.0, 6590.0, 6590.0],
#   [6560.0, 6560.0, 6582.5, 6582.5],
#   [6532.5, 6532.5, 6571.25, 6571.25],
#   [6605.0, 6605.0, 6615.0, 6615.0],
#   [6625.0, 6625.0, 6635.0, 6635.0],
#   [6610.0, 6610.0, 6630.0, 6630.0],
#   [6645.0, 6645.0, 6655.0, 6655.0],
#   [6675.0, 6675.0, 6685.0, 6685.0],
#   [6665.0, 6665.0, 6680.0, 6680.0],
#   [6650.0, 6650.0, 6672.5, 6672.5],
#   [6620.0, 6620.0, 6661.25, 6661.25],
#   [6551.875, 6551.875, 6640.625, 6640.625],
#   [6695.0, 6695.0, 6705.0, 6705.0],
#   [6725.0, 6725.0, 6735.0, 6735.0],
#   [6715.0, 6715.0, 6730.0, 6730.0],
#   [6700.0, 6700.0, 6722.5, 6722.5],
#   [6745.0, 6745.0, 6755.0, 6755.0],
#   [6765.0, 6765.0, 6775.0, 6775.0],
#   [6750.0, 6750.0, 6770.0, 6770.0],
#   [6711.25, 6711.25, 6760.0, 6760.0],
#   [6795.0, 6795.0, 6805.0, 6805.0],
#   [6785.0, 6785.0, 6800.0, 6800.0],
#   [6815.0, 6815.0, 6825.0, 6825.0],
#   [6835.0, 6835.0, 6845.0, 6845.0],
#   [6820.0, 6820.0, 6840.0, 6840.0],
#   [6792.5, 6792.5, 6830.0, 6830.0],
#   [6735.625, 6735.625, 6811.25, 6811.25],
#   [6596.25, 6596.25, 6773.4375, 6773.4375],
#   [6216.875, 6216.875, 6684.84375, 6684.84375],
#   [5609.0625, 5609.0625, 6450.859375, 6450.859375],
#   [6855.0, 6855.0, 6865.0, 6865.0],
#   [6875.0, 6875.0, 6885.0, 6885.0],
#   [6895.0, 6895.0, 6905.0, 6905.0],
#   [6880.0, 6880.0, 6900.0, 6900.0],
#   [6860.0, 6860.0, 6890.0, 6890.0],
#   [6915.0, 6915.0, 6925.0, 6925.0],
#   [6935.0, 6935.0, 6945.0, 6945.0],
#   [6955.0, 6955.0, 6965.0, 6965.0],
#   [6975.0, 6975.0, 6985.0, 6985.0],
#   [6960.0, 6960.0, 6980.0, 6980.0],
#   [6940.0, 6940.0, 6970.0, 6970.0],
#   [6920.0, 6920.0, 6955.0, 6955.0],
#   [6875.0, 6875.0, 6937.5, 6937.5],
#   [6995.0, 6995.0, 7005.0, 7005.0],
#   [7015.0, 7015.0, 7025.0, 7025.0],
#   [7000.0, 7000.0, 7020.0, 7020.0],
#   [7045.0, 7045.0, 7055.0, 7055.0],
#   [7075.0, 7075.0, 7085.0, 7085.0],
#   [7065.0, 7065.0, 7080.0, 7080.0],
#   [7050.0, 7050.0, 7072.5, 7072.5],
#   [7035.0, 7035.0, 7061.25, 7061.25],
#   [7095.0, 7095.0, 7105.0, 7105.0],
#   [7115.0, 7115.0, 7125.0, 7125.0],
#   [7135.0, 7135.0, 7145.0, 7145.0],
#   [7120.0, 7120.0, 7140.0, 7140.0],
#   [7100.0, 7100.0, 7130.0, 7130.0],
#   [7048.125, 7048.125, 7115.0, 7115.0],
#   [7010.0, 7010.0, 7081.5625, 7081.5625],
#   [7155.0, 7155.0, 7165.0, 7165.0],
#   [7175.0, 7175.0, 7185.0, 7185.0],
#   [7160.0, 7160.0, 7180.0, 7180.0],
#   [7195.0, 7195.0, 7205.0, 7205.0],
#   [7215.0, 7215.0, 7225.0, 7225.0],
#   [7255.0, 7255.0, 7265.0, 7265.0],
#   [7245.0, 7245.0, 7260.0, 7260.0],
#   [7235.0, 7235.0, 7252.5, 7252.5],
#   [7220.0, 7220.0, 7243.75, 7243.75],
#   [7200.0, 7200.0, 7231.875, 7231.875],
#   [7170.0, 7170.0, 7215.9375, 7215.9375],
#   [7045.78125, 7045.78125, 7192.96875, 7192.96875],
#   [6906.25, 6906.25, 7119.375, 7119.375],
#   [7275.0, 7275.0, 7285.0, 7285.0],
#   [7305.0, 7305.0, 7315.0, 7315.0],
#   [7295.0, 7295.0, 7310.0, 7310.0],
#   [7280.0, 7280.0, 7302.5, 7302.5],
#   [7325.0, 7325.0, 7335.0, 7335.0],
#   [7345.0, 7345.0, 7355.0, 7355.0],
#   [7330.0, 7330.0, 7350.0, 7350.0],
#   [7375.0, 7375.0, 7385.0, 7385.0],
#   [7365.0, 7365.0, 7380.0, 7380.0],
#   [7395.0, 7395.0, 7405.0, 7405.0],
#   [7415.0, 7415.0, 7425.0, 7425.0],
#   [7400.0, 7400.0, 7420.0, 7420.0],
#   [7372.5, 7372.5, 7410.0, 7410.0],
#   [7340.0, 7340.0, 7391.25, 7391.25],
#   [7435.0, 7435.0, 7445.0, 7445.0],
#   [7455.0, 7455.0, 7465.0, 7465.0],
#   [7475.0, 7475.0, 7485.0, 7485.0],
#   [7460.0, 7460.0, 7480.0, 7480.0],
#   [7440.0, 7440.0, 7470.0, 7470.0],
#   [7495.0, 7495.0, 7505.0, 7505.0],
#   [7515.0, 7515.0, 7525.0, 7525.0],
#   [7500.0, 7500.0, 7520.0, 7520.0],
#   [7455.0, 7455.0, 7510.0, 7510.0],
#   [7365.625, 7365.625, 7482.5, 7482.5],
#   [7291.25, 7291.25, 7424.0625, 7424.0625],
#   [7555.0, 7555.0, 7565.0, 7565.0],
#   [7545.0, 7545.0, 7560.0, 7560.0],
#   [7535.0, 7535.0, 7552.5, 7552.5],
#   [7595.0, 7595.0, 7605.0, 7605.0],
#   [7585.0, 7585.0, 7600.0, 7600.0],
#   [7575.0, 7575.0, 7592.5, 7592.5],
#   [7543.75, 7543.75, 7583.75, 7583.75],
#   [7625.0, 7625.0, 7635.0, 7635.0],
#   [7615.0, 7615.0, 7630.0, 7630.0],
#   [7655.0, 7655.0, 7665.0, 7665.0],
#   [7645.0, 7645.0, 7660.0, 7660.0],
#   [7622.5, 7622.5, 7652.5, 7652.5],
#   [7675.0, 7675.0, 7685.0, 7685.0],
#   [7695.0, 7695.0, 7705.0, 7705.0],
#   [7725.0, 7725.0, 7735.0, 7735.0],
#   [7715.0, 7715.0, 7730.0, 7730.0],
#   [7700.0, 7700.0, 7722.5, 7722.5],
#   [7680.0, 7680.0, 7711.25, 7711.25],
#   [7745.0, 7745.0, 7755.0, 7755.0],
#   [7765.0, 7765.0, 7775.0, 7775.0],
#   [7750.0, 7750.0, 7770.0, 7770.0],
#   [7695.625, 7695.625, 7760.0, 7760.0],
#   [7637.5, 7637.5, 7727.8125, 7727.8125],
#   [7563.75, 7563.75, 7682.65625, 7682.65625],
#   [7357.65625, 7357.65625, 7623.203125, 7623.203125],
#   [7785.0, 7785.0, 7795.0, 7795.0],
#   [7815.0, 7815.0, 7825.0, 7825.0],
#   [7805.0, 7805.0, 7820.0, 7820.0],
#   [7790.0, 7790.0, 7812.5, 7812.5],
#   [7835.0, 7835.0, 7845.0, 7845.0],
#   [7855.0, 7855.0, 7865.0, 7865.0],
#   [7875.0, 7875.0, 7885.0, 7885.0],
#   [7895.0, 7895.0, 7905.0, 7905.0],
#   [7880.0, 7880.0, 7900.0, 7900.0],
#   [7860.0, 7860.0, 7890.0, 7890.0],
#   [7840.0, 7840.0, 7875.0, 7875.0],
#   [7801.25, 7801.25, 7857.5, 7857.5],
#   [7915.0, 7915.0, 7925.0, 7925.0],
#   [7935.0, 7935.0, 7945.0, 7945.0],
#   [7920.0, 7920.0, 7940.0, 7940.0],
#   [7955.0, 7955.0, 7965.0, 7965.0],
#   [7975.0, 7975.0, 7985.0, 7985.0],
#   [7960.0, 7960.0, 7980.0, 7980.0],
#   [7995.0, 7995.0, 8005.0, 8005.0],
#   [8015.0, 8015.0, 8025.0, 8025.0],
#   [8000.0, 8000.0, 8020.0, 8020.0],
#   [7970.0, 7970.0, 8010.0, 8010.0],
#   [8035.0, 8035.0, 8045.0, 8045.0],
#   [8065.0, 8065.0, 8075.0, 8075.0],
#   [8095.0, 8095.0, 8105.0, 8105.0],
#   [8085.0, 8085.0, 8100.0, 8100.0],
#   [8070.0, 8070.0, 8092.5, 8092.5],
#   [8055.0, 8055.0, 8081.25, 8081.25],
#   [8040.0, 8040.0, 8068.125, 8068.125],
#   [7990.0, 7990.0, 8054.0625, 8054.0625],
#   [7930.0, 7930.0, 8022.03125, 8022.03125],
#   [7829.375, 7829.375, 7976.015625, 7976.015625],
#   [7490.4296875, 7490.4296875, 7902.6953125, 7902.6953125],
#   [7012.8125, 7012.8125, 7696.5625, 7696.5625],
#   [6029.9609375, 6029.9609375, 7354.6875, 7354.6875],
#   [4636.4599609375, 4636.4599609375, 6692.32421875, 6692.32421875],
#   [8115.0, 8115.0, 8125.0, 8125.0],
#   [8155.0, 8155.0, 8165.0, 8165.0],
#   [8145.0, 8145.0, 8160.0, 8160.0],
#   [8135.0, 8135.0, 8152.5, 8152.5],
#   [8120.0, 8120.0, 8143.75, 8143.75],
#   [8175.0, 8175.0, 8185.0, 8185.0],
#   [8195.0, 8195.0, 8205.0, 8205.0],
#   [8180.0, 8180.0, 8200.0, 8200.0],
#   [8225.0, 8225.0, 8235.0, 8235.0],
#   [8215.0, 8215.0, 8230.0, 8230.0],
#   [8245.0, 8245.0, 8255.0, 8255.0],
#   [8265.0, 8265.0, 8275.0, 8275.0],
#   [8250.0, 8250.0, 8270.0, 8270.0],
#   [8222.5, 8222.5, 8260.0, 8260.0],
#   [8305.0, 8305.0, 8315.0, 8315.0],
#   [8295.0, 8295.0, 8310.0, 8310.0],
#   [8285.0, 8285.0, 8302.5, 8302.5],
#   [8241.25, 8241.25, 8293.75, 8293.75],
#   [8190.0, 8190.0, 8267.5, 8267.5],
#   [8131.875, 8131.875, 8228.75, 8228.75],
#   [8335.0, 8335.0, 8345.0, 8345.0],
#   [8325.0, 8325.0, 8340.0, 8340.0],
#   [8365.0, 8365.0, 8375.0, 8375.0],
#   [8355.0, 8355.0, 8370.0, 8370.0],
#   [8385.0, 8385.0, 8395.0, 8395.0],
#   [8362.5, 8362.5, 8390.0, 8390.0],
#   [8332.5, 8332.5, 8376.25, 8376.25],
#   [8415.0, 8415.0, 8425.0, 8425.0],
#   [8405.0, 8405.0, 8420.0, 8420.0],
#   [8435.0, 8435.0, 8445.0, 8445.0],
#   [8455.0, 8455.0, 8465.0, 8465.0],
#   [8440.0, 8440.0, 8460.0, 8460.0],
#   [8412.5, 8412.5, 8450.0, 8450.0],
#   [8354.375, 8354.375, 8431.25, 8431.25],
#   [8475.0, 8475.0, 8485.0, 8485.0],
#   [8495.0, 8495.0, 8505.0, 8505.0],
#   [8535.0, 8535.0, 8545.0, 8545.0],
#   [8525.0, 8525.0, 8540.0, 8540.0],
#   [8515.0, 8515.0, 8532.5, 8532.5],
#   [8500.0, 8500.0, 8523.75, 8523.75],
#   [8480.0, 8480.0, 8511.875, 8511.875],
#   [8565.0, 8565.0, 8575.0, 8575.0],
#   [8555.0, 8555.0, 8570.0, 8570.0],
#   [8595.0, 8595.0, 8605.0, 8605.0],
#   [8585.0, 8585.0, 8600.0, 8600.0],
#   [8625.0, 8625.0, 8635.0, 8635.0],
#   [8615.0, 8615.0, 8630.0, 8630.0],
#   [8592.5, 8592.5, 8622.5, 8622.5],
#   [8562.5, 8562.5, 8607.5, 8607.5],
#   [8495.9375, 8495.9375, 8585.0, 8585.0],
#   [8392.8125, 8392.8125, 8540.46875, 8540.46875],
#   [8180.3125, 8180.3125, 8466.640625, 8466.640625],
#   [8645.0, 8645.0, 8655.0, 8655.0],
#   [8675.0, 8675.0, 8685.0, 8685.0],
#   [8665.0, 8665.0, 8680.0, 8680.0],
#   [8650.0, 8650.0, 8672.5, 8672.5],
#   [8695.0, 8695.0, 8705.0, 8705.0],
#   [8715.0, 8715.0, 8725.0, 8725.0],
#   [8735.0, 8735.0, 8745.0, 8745.0],
#   [8720.0, 8720.0, 8740.0, 8740.0],
#   [8700.0, 8700.0, 8730.0, 8730.0],
#   [8661.25, 8661.25, 8715.0, 8715.0],
#   [8765.0, 8765.0, 8775.0, 8775.0],
#   [8755.0, 8755.0, 8770.0, 8770.0],
#   [8785.0, 8785.0, 8795.0, 8795.0],
#   [8805.0, 8805.0, 8815.0, 8815.0],
#   [8825.0, 8825.0, 8835.0, 8835.0],
#   [8810.0, 8810.0, 8830.0, 8830.0],
#   [8790.0, 8790.0, 8820.0, 8820.0],
#   [8762.5, 8762.5, 8805.0, 8805.0],
#   [8688.125, 8688.125, 8783.75, 8783.75],
#   [8845.0, 8845.0, 8855.0, 8855.0],
#   [8875.0, 8875.0, 8885.0, 8885.0],
#   [8865.0, 8865.0, 8880.0, 8880.0],
#   [8895.0, 8895.0, 8905.0, 8905.0],
#   [8925.0, 8925.0, 8935.0, 8935.0],
#   [8915.0, 8915.0, 8930.0, 8930.0],
#   [8900.0, 8900.0, 8922.5, 8922.5],
#   [8872.5, 8872.5, 8911.25, 8911.25],
#   [8850.0, 8850.0, 8891.875, 8891.875],
#   [8945.0, 8945.0, 8955.0, 8955.0],
#   [8975.0, 8975.0, 8985.0, 8985.0],
#   [8965.0, 8965.0, 8980.0, 8980.0],
#   [8950.0, 8950.0, 8972.5, 8972.5],
#   [8995.0, 8995.0, 9005.0, 9005.0],
#   [9025.0, 9025.0, 9035.0, 9035.0],
#   [9015.0, 9015.0, 9030.0, 9030.0],
#   [9045.0, 9045.0, 9055.0, 9055.0],
#   [9065.0, 9065.0, 9075.0, 9075.0],
#   [9050.0, 9050.0, 9070.0, 9070.0],
#   [9022.5, 9022.5, 9060.0, 9060.0],
#   [9000.0, 9000.0, 9041.25, 9041.25],
#   [8961.25, 8961.25, 9020.625, 9020.625],
#   [8870.9375, 8870.9375, 8990.9375, 8990.9375],
#   [9085.0, 9085.0, 9095.0, 9095.0],
#   [9105.0, 9105.0, 9115.0, 9115.0],
#   [9125.0, 9125.0, 9135.0, 9135.0],
#   [9110.0, 9110.0, 9130.0, 9130.0],
#   [9090.0, 9090.0, 9120.0, 9120.0],
#   [9145.0, 9145.0, 9155.0, 9155.0],
#   [9165.0, 9165.0, 9175.0, 9175.0],
#   [9185.0, 9185.0, 9195.0, 9195.0],
#   [9170.0, 9170.0, 9190.0, 9190.0],
#   [9150.0, 9150.0, 9180.0, 9180.0],
#   [9105.0, 9105.0, 9165.0, 9165.0],
#   [9205.0, 9205.0, 9215.0, 9215.0],
#   [9245.0, 9245.0, 9255.0, 9255.0],
#   [9235.0, 9235.0, 9250.0, 9250.0],
#   [9265.0, 9265.0, 9275.0, 9275.0],
#   [9285.0, 9285.0, 9295.0, 9295.0],
#   [9270.0, 9270.0, 9290.0, 9290.0],
#   [9242.5, 9242.5, 9280.0, 9280.0],
#   [9225.0, 9225.0, 9261.25, 9261.25],
#   [9210.0, 9210.0, 9243.125, 9243.125],
#   [9315.0, 9315.0, 9325.0, 9325.0],
#   [9305.0, 9305.0, 9320.0, 9320.0],
#   [9226.5625, 9226.5625, 9312.5, 9312.5],
#   [9135.0, 9135.0, 9269.53125, 9269.53125],
#   [8930.9375, 8930.9375, 9202.265625, 9202.265625],
#   [8735.9375, 8735.9375, 9066.6015625, 9066.6015625],
#   [8323.4765625, 8323.4765625, 8901.26953125, 8901.26953125],
#   [9345.0, 9345.0, 9355.0, 9355.0],
#   [9335.0, 9335.0, 9350.0, 9350.0],
#   [9365.0, 9365.0, 9375.0, 9375.0],
#   [9385.0, 9385.0, 9395.0, 9395.0],
#   [9405.0, 9405.0, 9415.0, 9415.0],
#   [9425.0, 9425.0, 9435.0, 9435.0],
#   [9410.0, 9410.0, 9430.0, 9430.0],
#   [9390.0, 9390.0, 9420.0, 9420.0],
#   [9370.0, 9370.0, 9405.0, 9405.0],
#   [9342.5, 9342.5, 9387.5, 9387.5],
#   [9455.0, 9455.0, 9465.0, 9465.0],
#   [9475.0, 9475.0, 9485.0, 9485.0],
#   [9460.0, 9460.0, 9480.0, 9480.0],
#   [9445.0, 9445.0, 9470.0, 9470.0],
#   [9505.0, 9505.0, 9515.0, 9515.0],
#   [9495.0, 9495.0, 9510.0, 9510.0],
#   [9525.0, 9525.0, 9535.0, 9535.0],
#   [9545.0, 9545.0, 9555.0, 9555.0],
#   [9530.0, 9530.0, 9550.0, 9550.0],
#   [9502.5, 9502.5, 9540.0, 9540.0],
#   [9457.5, 9457.5, 9521.25, 9521.25],
#   [9365.0, 9365.0, 9489.375, 9489.375],
#   [9565.0, 9565.0, 9575.0, 9575.0],
#   [9585.0, 9585.0, 9595.0, 9595.0],
#   [9615.0, 9615.0, 9625.0, 9625.0],
#   [9605.0, 9605.0, 9620.0, 9620.0],
#   [9590.0, 9590.0, 9612.5, 9612.5],
#   [9570.0, 9570.0, 9601.25, 9601.25],
#   [9635.0, 9635.0, 9645.0, 9645.0],
#   [9665.0, 9665.0, 9675.0, 9675.0],
#   [9655.0, 9655.0, 9670.0, 9670.0],
#   [9705.0, 9705.0, 9715.0, 9715.0],
#   [9695.0, 9695.0, 9710.0, 9710.0],
#   [9685.0, 9685.0, 9702.5, 9702.5],
#   [9662.5, 9662.5, 9693.75, 9693.75],
#   [9640.0, 9640.0, 9678.125, 9678.125],
#   [9585.625, 9585.625, 9659.0625, 9659.0625],
#   [9427.1875, 9427.1875, 9622.34375, 9622.34375],
#   [9725.0, 9725.0, 9735.0, 9735.0],
#   [9755.0, 9755.0, 9765.0, 9765.0],
#   [9775.0, 9775.0, 9785.0, 9785.0],
#   [9760.0, 9760.0, 9780.0, 9780.0],
#   [9745.0, 9745.0, 9770.0, 9770.0],
#   [9730.0, 9730.0, 9757.5, 9757.5],
#   [9805.0, 9805.0, 9815.0, 9815.0],
#   [9795.0, 9795.0, 9810.0, 9810.0],
#   [9825.0, 9825.0, 9835.0, 9835.0],
#   [9845.0, 9845.0, 9855.0, 9855.0],
#   [9875.0, 9875.0, 9885.0, 9885.0],
#   [9865.0, 9865.0, 9880.0, 9880.0],
#   [9850.0, 9850.0, 9872.5, 9872.5],
#   [9830.0, 9830.0, 9861.25, 9861.25],
#   [9802.5, 9802.5, 9845.625, 9845.625],
#   [9743.75, 9743.75, 9824.0625, 9824.0625],
#   [9895.0, 9895.0, 9905.0, 9905.0],
#   [9915.0, 9915.0, 9925.0, 9925.0],
#   [9935.0, 9935.0, 9945.0, 9945.0],
#   [9920.0, 9920.0, 9940.0, 9940.0],
#   [9900.0, 9900.0, 9930.0, 9930.0],
#   [9965.0, 9965.0, 9975.0, 9975.0],
#   [9955.0, 9955.0, 9970.0, 9970.0],
#   [9985.0, 9985.0, 9995.0, 9995.0],
#   [10015.0, 10015.0, 10025.0, 10025.0],
#   [10005.0, 10005.0, 10020.0, 10020.0],
#   [9990.0, 9990.0, 10012.5, 10012.5],
#   [9962.5, 9962.5, 10001.25, 10001.25],
#   [9915.0, 9915.0, 9981.875, 9981.875],
#   [10035.0, 10035.0, 10045.0, 10045.0],
#   [10055.0, 10055.0, 10065.0, 10065.0],
#   [10075.0, 10075.0, 10085.0, 10085.0],
#   ...],
#  'dcoord': [[0.0, 7.205146495861328, 7.205146495861328, 0.0],
#   [0.0, 8.579819202057188, 8.579819202057188, 7.205146495861328],
#   [0.0, 4.348322774509908, 4.348322774509908, 0.0],
#   [0.0, 6.984746944286685, 6.984746944286685, 0.0],
#   [4.348322774509908, 7.20084532841503, 7.20084532841503, 6.984746944286685],
#   [0.0, 8.226344701175723, 8.226344701175723, 0.0],
#   [7.20084532841503,
#    10.915255031530005,
#    10.915255031530005,
#    8.226344701175723],
#   [8.579819202057188,
#    12.886452733923141,
#    12.886452733923141,
#    10.915255031530005],
#   [0.0, 7.230787743597612, 7.230787743597612, 0.0],
#   [0.0, 9.508152273256867, 9.508152273256867, 7.230787743597612],
#   [0.0, 10.341464025654224, 10.341464025654224, 9.508152273256867],
#   [0.0, 10.555599618565779, 10.555599618565779, 10.341464025654224],
#   [0.0, 7.9663143033856265, 7.9663143033856265, 0.0],
#   [0.0, 8.05801167966081, 8.05801167966081, 0.0],
#   [0.0, 8.738334063266414, 8.738334063266414, 8.05801167966081],
#   [7.9663143033856265,
#    11.964572243748641,
#    11.964572243748641,
#    8.738334063266414],
#   [10.555599618565779,
#    12.891174122845161,
#    12.891174122845161,
#    11.964572243748641],
#   [12.886452733923141,
#    19.196290809313837,
#    19.196290809313837,
#    12.891174122845161],
#   [0.0, 6.438654557416074, 6.438654557416074, 0.0],
#   [0.0, 7.652734455730833, 7.652734455730833, 0.0],
#   [6.438654557416074, 10.76553539935786, 10.76553539935786, 7.652734455730833],
#   [0.0, 6.613965320961547, 6.613965320961547, 0.0],
#   [0.0, 9.46519637788532, 9.46519637788532, 6.613965320961547],
#   [0.0, 6.63761193748366, 6.63761193748366, 0.0],
#   [0.0, 8.058061640386475, 8.058061640386475, 6.63761193748366],
#   [0.0, 5.747376621612413, 5.747376621612413, 0.0],
#   [0.0, 6.9597287829086145, 6.9597287829086145, 0.0],
#   [5.747376621612413,
#    9.352883079593388,
#    9.352883079593388,
#    6.9597287829086145],
#   [8.058061640386475, 10.61944606988372, 10.61944606988372, 9.352883079593388],
#   [9.46519637788532,
#    12.833414507082045,
#    12.833414507082045,
#    10.61944606988372],
#   [10.76553539935786,
#    13.536134543784526,
#    13.536134543784526,
#    12.833414507082045],
#   [0.0, 5.670389089682996, 5.670389089682996, 0.0],
#   [0.0, 5.115767870604059, 5.115767870604059, 0.0],
#   [0.0, 7.471654640082474, 7.471654640082474, 5.115767870604059],
#   [5.670389089682996, 7.858720122788137, 7.858720122788137, 7.471654640082474],
#   [0.0, 5.318901978793836, 5.318901978793836, 0.0],
#   [0.0, 7.042732953950129, 7.042732953950129, 0.0],
#   [5.318901978793836, 9.435403370109794, 9.435403370109794, 7.042732953950129],
#   [0.0, 5.609233604683535, 5.609233604683535, 0.0],
#   [0.0, 7.68383471088603, 7.68383471088603, 0.0],
#   [5.609233604683535, 8.870042298773638, 8.870042298773638, 7.68383471088603],
#   [0.0, 6.311256902215172, 6.311256902215172, 0.0],
#   [0.0, 7.102551103844488, 7.102551103844488, 6.311256902215172],
#   [0.0, 5.802240723454041, 5.802240723454041, 0.0],
#   [0.0, 5.988685496369366, 5.988685496369366, 5.802240723454041],
#   [0.0, 4.855328664392156, 4.855328664392156, 0.0],
#   [0.0, 6.045016884481759, 6.045016884481759, 0.0],
#   [4.855328664392156, 7.113554293767118, 7.113554293767118, 6.045016884481759],
#   [5.988685496369366, 7.7295753782112, 7.7295753782112, 7.113554293767118],
#   [7.102551103844488, 9.460100193938572, 9.460100193938572, 7.7295753782112],
#   [8.870042298773638,
#    11.500609142453275,
#    11.500609142453275,
#    9.460100193938572],
#   [9.435403370109794,
#    12.593065555738907,
#    12.593065555738907,
#    11.500609142453275],
#   [7.858720122788137,
#    14.866788405699765,
#    14.866788405699765,
#    12.593065555738907],
#   [13.536134543784526,
#    16.64571897189253,
#    16.64571897189253,
#    14.866788405699765],
#   [0.0, 5.195840750693253, 5.195840750693253, 0.0],
#   [0.0, 5.173509760544299, 5.173509760544299, 0.0],
#   [0.0, 6.186050623685457, 6.186050623685457, 5.173509760544299],
#   [0.0, 7.649301755723054, 7.649301755723054, 0.0],
#   [6.186050623685457, 9.278512545497799, 9.278512545497799, 7.649301755723054],
#   [5.195840750693253, 10.98444803754743, 10.98444803754743, 9.278512545497799],
#   [0.0, 6.577508867163823, 6.577508867163823, 0.0],
#   [0.0, 9.26017416461907, 9.26017416461907, 6.577508867163823],
#   [0.0, 7.838686429931514, 7.838686429931514, 0.0],
#   [0.0, 5.936015708311064, 5.936015708311064, 0.0],
#   [0.0, 5.348240700536627, 5.348240700536627, 0.0],
#   [0.0, 6.457930993094187, 6.457930993094187, 5.348240700536627],
#   [5.936015708311064, 8.508446470081305, 8.508446470081305, 6.457930993094187],
#   [7.838686429931514,
#    10.194511685214998,
#    10.194511685214998,
#    8.508446470081305],
#   [9.26017416461907,
#    11.634192474053707,
#    11.634192474053707,
#    10.194511685214998],
#   [10.98444803754743,
#    14.83223534932433,
#    14.83223534932433,
#    11.634192474053707],
#   [0.0, 5.286246720326691, 5.286246720326691, 0.0],
#   [0.0, 6.704954651448723, 6.704954651448723, 5.286246720326691],
#   [0.0, 5.621268447639619, 5.621268447639619, 0.0],
#   [0.0, 6.827185328464352, 6.827185328464352, 5.621268447639619],
#   [6.704954651448723, 8.170748514194386, 8.170748514194386, 6.827185328464352],
#   [0.0, 4.746157646787092, 4.746157646787092, 0.0],
#   [0.0, 5.069542014044675, 5.069542014044675, 0.0],
#   [4.746157646787092, 8.481641052057448, 8.481641052057448, 5.069542014044675],
#   [8.170748514194386,
#    11.701938277707523,
#    11.701938277707523,
#    8.481641052057448],
#   [0.0, 5.785034393398583, 5.785034393398583, 0.0],
#   [0.0, 6.714156098251316, 6.714156098251316, 5.785034393398583],
#   [0.0, 5.292905078086577, 5.292905078086577, 0.0],
#   [0.0, 6.841603305007538, 6.841603305007538, 0.0],
#   [5.292905078086577, 7.906660989327465, 7.906660989327465, 6.841603305007538],
#   [6.714156098251316, 9.321400407241308, 9.321400407241308, 7.906660989327465],
#   [0.0, 4.959959530769706, 4.959959530769706, 0.0],
#   [0.0, 6.341222827667444, 6.341222827667444, 0.0],
#   [0.0, 5.579394075249317, 5.579394075249317, 0.0],
#   [0.0, 6.720051757858095, 6.720051757858095, 5.579394075249317],
#   [0.0, 7.394718308787881, 7.394718308787881, 6.720051757858095],
#   [6.341222827667444, 8.433204678415139, 8.433204678415139, 7.394718308787881],
#   [4.959959530769706, 9.396081615840604, 9.396081615840604, 8.433204678415139],
#   [9.321400407241308,
#    12.021969215881654,
#    12.021969215881654,
#    9.396081615840604],
#   [11.701938277707523,
#    13.114607422873092,
#    13.114607422873092,
#    12.021969215881654],
#   [0.0, 5.584720894715632, 5.584720894715632, 0.0],
#   [0.0, 6.483058575606895, 6.483058575606895, 5.584720894715632],
#   [0.0, 6.870630847227326, 6.870630847227326, 0.0],
#   [0.0, 7.244182175272798, 7.244182175272798, 6.870630847227326],
#   [6.483058575606895, 8.901921124652095, 8.901921124652095, 7.244182175272798],
#   [0.0, 9.893084973307422, 9.893084973307422, 8.901921124652095],
#   [0.0, 9.082916337999897, 9.082916337999897, 0.0],
#   [0.0, 4.921096591874351, 4.921096591874351, 0.0],
#   [0.0, 6.762976366636542, 6.762976366636542, 0.0],
#   [0.0, 8.175129983113804, 8.175129983113804, 6.762976366636542],
#   [4.921096591874351,
#    10.089573104713205,
#    10.089573104713205,
#    8.175129983113804],
#   [9.082916337999897,
#    12.313699318331246,
#    12.313699318331246,
#    10.089573104713205],
#   [9.893084973307422,
#    13.61456892781143,
#    13.61456892781143,
#    12.313699318331246],
#   [13.114607422873092,
#    17.731961657937504,
#    17.731961657937504,
#    13.61456892781143],
#   [14.83223534932433,
#    20.092806985802955,
#    20.092806985802955,
#    17.731961657937504],
#   [16.64571897189253,
#    24.211275483744934,
#    24.211275483744934,
#    20.092806985802955],
#   [19.196290809313837,
#    29.667603299263835,
#    29.667603299263835,
#    24.211275483744934],
#   [0.0, 5.051487907019872, 5.051487907019872, 0.0],
#   [0.0, 5.190728341703065, 5.190728341703065, 0.0],
#   [0.0, 6.014106567258266, 6.014106567258266, 5.190728341703065],
#   [0.0, 6.6673514818883275, 6.6673514818883275, 6.014106567258266],
#   [5.051487907019872,
#    8.471396505826059,
#    8.471396505826059,
#    6.6673514818883275],
#   [0.0, 5.546034434350083, 5.546034434350083, 0.0],
#   [0.0, 6.197138358604581, 6.197138358604581, 5.546034434350083],
#   [0.0, 8.0479039184763, 8.0479039184763, 6.197138358604581],
#   [0.0, 5.108861621678775, 5.108861621678775, 0.0],
#   [0.0, 7.402021764833081, 7.402021764833081, 5.108861621678775],
#   [0.0, 5.929284856340667, 5.929284856340667, 0.0],
#   [0.0, 6.108184244368209, 6.108184244368209, 0.0],
#   [5.929284856340667, 7.726733378876228, 7.726733378876228, 6.108184244368209],
#   [7.402021764833081,
#    10.141548394479093,
#    10.141548394479093,
#    7.726733378876228],
#   [8.0479039184763,
#    11.480612022301395,
#    11.480612022301395,
#    10.141548394479093],
#   [8.471396505826059,
#    12.20413776067822,
#    12.20413776067822,
#    11.480612022301395],
#   [0.0, 5.997347679194545, 5.997347679194545, 0.0],
#   [0.0, 5.361449387119442, 5.361449387119442, 0.0],
#   [0.0, 7.359599000091588, 7.359599000091588, 5.361449387119442],
#   [5.997347679194545, 8.589499103346457, 8.589499103346457, 7.359599000091588],
#   [0.0, 6.5236514060395985, 6.5236514060395985, 0.0],
#   [0.0, 5.6311610794584, 5.6311610794584, 0.0],
#   [0.0, 7.809029214372197, 7.809029214372197, 5.6311610794584],
#   [6.5236514060395985,
#    10.429742743673852,
#    10.429742743673852,
#    7.809029214372197],
#   [0.0, 6.019140058609848, 6.019140058609848, 0.0],
#   [0.0, 6.271899873750508, 6.271899873750508, 0.0],
#   [6.019140058609848, 8.463975389194967, 8.463975389194967, 6.271899873750508],
#   [0.0, 5.00641727021643, 5.00641727021643, 0.0],
#   [0.0, 5.046246825625675, 5.046246825625675, 0.0],
#   [5.00641727021643, 8.731662891303984, 8.731662891303984, 5.046246825625675],
#   [8.463975389194967,
#    11.384706547869735,
#    11.384706547869735,
#    8.731662891303984],
#   [10.429742743673852,
#    12.986251552102205,
#    12.986251552102205,
#    11.384706547869735],
#   [8.589499103346457,
#    15.256260306135859,
#    15.256260306135859,
#    12.986251552102205],
#   [0.0, 5.763557343902701, 5.763557343902701, 0.0],
#   [0.0, 7.95870837998908, 7.95870837998908, 0.0],
#   [0.0, 6.373754924954219, 6.373754924954219, 0.0],
#   [0.0, 5.921814885839851, 5.921814885839851, 0.0],
#   [0.0, 4.8570648384354405, 4.8570648384354405, 0.0],
#   [0.0, 7.005012657436815, 7.005012657436815, 4.8570648384354405],
# ...
#   'C6',
#   'C6',
#   'C6',
#   'C6',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C7',
#   'C8',
#   'C8',
#   'C8',
#   'C8',
#   'C0',
#   'C9',
#   'C9',
#   'C1',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C0',
#   'C0',
#   'C0',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C4',
#   'C4',
#   'C4',
#   'C0',
#   'C5',
#   'C5',
#   'C5',
#   'C5',
#   'C5',
#   'C5',
#   'C6',
#   'C6',
#   'C6',
#   'C6',
#   'C6',
#   'C6',
#   'C6',
#   'C0',
#   'C0',
#   'C7',
#   'C7',
#   'C7',
#   'C7',
#   'C7',
#   'C7',
#   'C8',
#   'C9',
#   'C1',
#   'C1',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C3',
#   'C3',
#   'C3',
#   'C4',
#   'C4',
#   'C5',
#   'C5',
#   'C5',
#   'C0',
#   'C0',
#   'C0',
#   'C6',
#   'C6',
#   'C6',
#   'C6',
#   'C7',
#   'C8',
#   'C8',
#   'C0',
#   'C9',
#   'C9',
#   'C9',
#   'C1',
#   'C1',
#   'C1',
#   'C0',
#   'C0',
#   'C0',
#   'C2',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C0',
#   'C4',
#   'C4',
#   'C5',
#   'C5',
#   'C5',
#   'C5',
#   'C5',
#   'C6',
#   'C6',
#   'C6',
#   'C6',
#   'C0',
#   'C0',
#   'C0',
#   'C7',
#   'C0',
#   'C8',
#   'C8',
#   'C9',
#   'C9',
#   'C9',
#   'C9',
#   'C9',
#   'C9',
#   'C1',
#   'C2',
#   'C2',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C5',
#   'C5',
#   'C5',
#   'C5',
#   'C5',
#   'C5',
#   'C5',
#   'C0',
#   'C0',
#   'C6',
#   'C6',
#   'C0',
#   'C7',
#   'C7',
#   'C8',
#   'C9',
#   'C9',
#   'C9',
#   'C9',
#   'C9',
#   'C9',
#   'C0',
#   'C0',
#   'C0',
#   'C1',
#   'C1',
#   'C2',
#   'C2',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C0',
#   'C0',
#   'C0',
#   'C5',
#   'C0',
#   'C6',
#   'C7',
#   'C7',
#   'C0',
#   'C8',
#   'C8',
#   'C8',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C9',
#   'C1',
#   'C2',
#   'C3',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C4',
#   'C4',
#   'C5',
#   'C6',
#   'C6',
#   'C6',
#   'C6',
#   'C0',
#   'C0',
#   'C7',
#   'C7',
#   'C7',
#   'C7',
#   'C8',
#   'C9',
#   'C9',
#   'C0',
#   'C0',
#   'C0',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C0',
#   'C3',
#   'C4',
#   'C4',
#   'C0',
#   'C5',
#   'C5',
#   'C6',
#   'C6',
#   'C6',
#   'C6',
#   'C6',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C7',
#   'C7',
#   'C7',
#   'C7',
#   'C7',
#   'C7',
#   'C8',
#   'C8',
#   'C8',
#   'C8',
#   'C8',
#   'C8',
#   'C8',
#   'C9',
#   'C1',
#   'C1',
#   'C1',
#   'C0',
#   'C0',
#   'C0',
#   'C2',
#   'C3',
#   'C4',
#   'C0',
#   'C0',
#   'C5',
#   'C6',
#   'C6',
#   'C6',
#   'C0',
#   'C0',
#   'C7',
#   'C7',
#   'C7',
#   'C7',
#   'C7',
#   'C8',
#   'C8',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C9',
#   'C9',
#   'C9',
#   'C9',
#   'C1',
#   'C1',
#   'C0',
#   'C2',
#   'C3',
#   'C3',
#   'C0',
#   'C4',
#   'C4',
#   'C4',
#   'C5',
#   'C6',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C7',
#   'C7',
#   'C8',
#   'C9',
#   'C9',
#   'C0',
#   'C0',
#   'C1',
#   'C2',
#   'C2',
#   'C0',
#   'C3',
#   'C4',
#   'C0',
#   'C0',
#   'C0',
#   'C5',
#   'C5',
#   'C6',
#   'C6',
#   'C6',
#   'C6',
#   'C0',
#   'C0',
#   'C7',
#   'C8',
#   'C8',
#   'C8',
#   'C0',
#   'C9',
#   'C0',
#   'C0',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C2',
#   'C2',
#   'C3',
#   'C3',
#   'C3',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C4',
#   'C5',
#   'C5',
#   'C0',
#   'C6',
#   'C7',
#   'C0',
#   'C8',
#   'C8',
#   'C0',
#   'C0',
#   'C9',
#   'C9',
#   'C0',
#   'C0',
#   'C0',
#   'C1',
#   'C1',
#   'C1',
#   'C0',
#   'C2',
#   'C2',
#   'C3',
#   'C3',
#   'C0',
#   'C0',
#   'C0',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C5',
#   'C6',
#   'C7',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C8',
#   'C9',
#   'C0',
#   'C0',
#   'C1',
#   'C1',
#   'C1',
#   'C2',
#   'C2',
#   'C3',
#   'C0',
#   'C0',
#   'C4',
#   'C0',
#   'C0',
#   'C5',
#   'C5',
#   'C6',
#   'C7',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C8',
#   'C9',
#   'C9',
#   'C1',
#   'C1',
#   'C0',
#   'C0',
#   'C2',
#   'C3',
#   'C3',
#   'C0',
#   'C4',
#   'C0',
#   'C5',
#   'C0',
#   'C6',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C7',
#   'C8',
#   'C8',
#   'C9',
#   'C1',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C2',
#   'C2',
#   'C2',
#   'C3',
#   'C4',
#   'C5',
#   'C5',
#   'C5',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C6',
#   'C7',
#   'C7',
#   'C7',
#   'C7',
#   'C7',
#   'C7',
#   'C0',
#   'C0',
#   'C8',
#   'C8',
#   'C0',
#   'C0',
#   'C9',
#   'C9',
#   'C1',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C4',
#   'C4',
#   'C4',
#   'C5',
#   'C6',
#   'C6',
#   'C0',
#   'C0',
#   'C0',
#   'C7',
#   'C8',
#   'C0',
#   'C9',
#   'C9',
#   'C0',
#   'C0',
#   'C0',
#   'C1',
#   'C1',
#   'C2',
#   'C3',
#   'C3',
#   'C0',
#   'C0',
#   'C4',
#   'C4',
#   'C4',
#   'C5',
#   'C5',
#   'C5',
#   'C5',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C6',
#   'C6',
#   'C7',
#   'C0',
#   'C0',
#   'C8',
#   'C9',
#   'C1',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C2',
#   'C3',
#   'C4',
#   'C5',
#   'C0',
#   'C0',
#   'C0',
#   'C6',
#   'C7',
#   'C7',
#   'C0',
#   'C8',
#   'C9',
#   'C0',
#   'C1',
#   'C2',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C3',
#   'C3',
#   'C0',
#   'C4',
#   'C5',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C6',
#   'C6',
#   'C7',
#   'C8',
#   'C0',
#   'C0',
#   'C0',
#   'C9',
#   'C1',
#   'C0',
#   'C2',
#   'C3',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C4',
#   'C5',
#   'C0',
#   'C0',
#   'C6',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C7',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C8',
#   'C9',
#   'C0',
#   'C0',
#   'C0',
#   'C1',
#   'C2',
#   'C3',
#   'C4',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C5',
#   'C6',
#   'C0',
#   'C7',
#   'C8',
#   'C8',
#   'C0',
#   'C0',
#   'C9',
#   'C1',
#   'C2',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C3',
#   'C4',
#   'C0',
#   'C0',
#   'C5',
#   'C6',
#   'C6',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C7',
#   'C0',
#   'C0',
#   'C0',
#   'C8',
#   'C9',
#   'C0',
#   'C1',
#   'C0',
#   'C2',
#   'C3',
#   'C0',
#   'C0',
#   'C0',
#   'C4',
#   'C5',
#   'C6',
#   'C0',
#   'C0',
#   'C7',
#   'C8',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C9',
#   'C9',
#   'C0',
#   'C1',
#   'C0',
#   'C0',
#   'C0',
#   'C2',
#   'C0',
#   'C3',
#   'C0',
#   'C0',
#   'C4',
#   'C5',
#   'C6',
#   'C6',
#   'C0',
#   'C0',
#   'C7',
#   'C8',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C9',
#   'C1',
#   'C0',
#   'C0',
#   'C2',
#   'C3',
#   'C4',
#   'C5',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C6',
#   'C6',
#   'C6',
#   'C7',
#   'C7',
#   'C7',
#   'C0',
#   'C8',
#   'C9',
#   'C9',
#   'C9',
#   'C9',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C1',
#   'C2',
#   'C2',
#   'C2',
#   'C0',
#   'C3',
#   'C4',
#   'C0',
#   'C5',
#   'C5',
#   'C5',
#   'C5',
#   'C5',
#   'C5',
#   'C6',
#   'C6',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C7',
#   'C7',
#   'C8',
#   'C8',
#   'C8',
#   'C8',
#   'C0',
#   'C9',
#   'C9',
#   'C1',
#   'C1',
#   'C1',
#   'C0',
#   'C0',
#   'C2',
#   'C3',
#   'C4',
#   'C4',
#   'C4',
#   'C0',
#   'C0',
#   'C5',
#   'C5',
#   'C6',
#   'C6',
#   'C6',
#   'C6',
#   'C6',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C7',
#   'C8',
#   'C8',
#   'C0',
#   'C9',
#   'C1',
#   'C1',
#   'C1',
#   'C0',
#   'C0',
#   'C2',
#   'C2',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C0',
#   'C0',
#   'C4',
#   'C5',
#   'C5',
#   'C6',
#   'C6',
#   'C6',
#   'C6',
#   'C0',
#   'C0',
#   'C7',
#   'C7',
#   'C7',
#   'C7',
#   'C8',
#   'C9',
#   'C9',
#   'C1',
#   'C1',
#   'C1',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C2',
#   'C3',
#   'C3',
#   'C3',
#   'C0',
#   'C4',
#   'C5',
#   'C5',
#   'C5',
#   'C0',
#   'C0',
#   'C6',
#   'C7',
#   'C7',
#   'C8',
#   'C9',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C1',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C2',
#   'C2',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C0',
#   'C4',
#   'C5',
#   'C0',
#   'C0',
#   'C6',
#   'C6',
#   'C7',
#   'C7',
#   'C7',
#   'C0',
#   'C0',
#   'C0',
#   'C8',
#   'C9',
#   'C1',
#   'C1',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C2',
#   'C2',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C4',
#   'C4',
#   'C5',
#   'C6',
#   'C6',
#   'C6',
#   'C6',
#   'C0',
#   'C0',
#   'C0',
#   'C7',
#   'C7',
#   'C7',
#   'C7',
#   'C7',
#   'C8',
#   'C8',
#   'C9',
#   'C1',
#   'C1',
#   'C0',
#   'C0',
#   'C0',
#   'C2',
#   'C2',
#   'C2',
#   ...],
#  'leaves_color_list': ['C1',
#   'C1',
#   'C1',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C3',
#   'C3',
#   'C0',
#   'C0',
#   'C4',
#   'C4',
#   'C4',
#   'C5',
#   'C5',
#   'C6',
#   'C6',
#   'C6',
#   'C7',
#   'C7',
#   'C8',
#   'C8',
#   'C9',
#   'C9',
#   'C9',
#   'C1',
#   'C1',
#   'C1',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C5',
#   'C5',
#   'C5',
#   'C5',
#   'C6',
#   'C6',
#   'C6',
#   'C6',
#   'C6',
#   'C6',
#   'C6',
#   'C6',
#   'C6',
#   'C6',
#   'C7',
#   'C7',
#   'C8',
#   'C8',
#   'C8',
#   'C8',
#   'C8',
#   'C9',
#   'C9',
#   'C9',
#   'C1',
#   'C1',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C5',
#   'C5',
#   'C5',
#   'C5',
#   'C5',
#   'C5',
#   'C5',
#   'C6',
#   'C6',
#   'C6',
#   'C6',
#   'C6',
#   'C6',
#   'C6',
#   'C6',
#   'C7',
#   'C7',
#   'C7',
#   'C7',
#   'C7',
#   'C7',
#   'C7',
#   'C8',
#   'C8',
#   'C9',
#   'C9',
#   'C1',
#   'C1',
#   'C1',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C4',
#   'C4',
#   'C4',
#   'C5',
#   'C5',
#   'C5',
#   'C5',
#   'C6',
#   'C6',
#   'C6',
#   'C6',
#   'C6',
#   'C7',
#   'C7',
#   'C8',
#   'C8',
#   'C8',
#   'C9',
#   'C9',
#   'C9',
#   'C9',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C2',
#   'C2',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C4',
#   'C4',
#   'C4',
#   'C5',
#   'C5',
#   'C5',
#   'C5',
#   'C5',
#   'C5',
#   'C6',
#   'C6',
#   'C6',
#   'C6',
#   'C6',
#   'C0',
#   'C7',
#   'C7',
#   'C8',
#   'C8',
#   'C8',
#   'C9',
#   'C9',
#   'C9',
#   'C9',
#   'C9',
#   'C9',
#   'C9',
#   'C1',
#   'C1',
#   'C2',
#   'C2',
#   'C2',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C5',
#   'C5',
#   'C5',
#   'C5',
#   'C5',
#   'C5',
#   'C5',
#   'C5',
#   'C0',
#   'C6',
#   'C6',
#   'C6',
#   'C7',
#   'C7',
#   'C7',
#   'C8',
#   'C8',
#   'C9',
#   'C9',
#   'C9',
#   'C9',
#   'C9',
#   'C9',
#   'C9',
#   'C1',
#   'C1',
#   'C1',
#   'C2',
#   'C2',
#   'C2',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C0',
#   'C5',
#   'C5',
#   'C6',
#   'C6',
#   'C7',
#   'C7',
#   'C7',
#   'C0',
#   'C8',
#   'C8',
#   'C8',
#   'C8',
#   'C9',
#   'C9',
#   'C1',
#   'C1',
#   'C2',
#   'C2',
#   'C0',
#   'C3',
#   'C3',
#   'C4',
#   'C4',
#   'C4',
#   'C5',
#   'C5',
#   'C6',
#   'C6',
#   'C6',
#   'C6',
#   'C6',
#   'C7',
#   'C7',
#   'C7',
#   'C7',
#   'C7',
#   'C8',
#   'C8',
#   'C9',
#   'C9',
#   'C9',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C3',
#   'C3',
#   'C4',
#   'C4',
#   'C4',
#   'C5',
#   'C5',
#   'C5',
#   'C6',
#   'C6',
#   'C6',
#   'C6',
#   'C6',
#   'C6',
#   'C7',
#   'C7',
#   'C7',
#   'C7',
#   'C7',
#   'C7',
#   'C7',
#   'C8',
#   'C8',
#   'C8',
#   'C8',
#   'C8',
#   'C8',
#   'C8',
#   'C8',
#   'C9',
#   'C9',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C2',
#   'C2',
#   'C3',
#   'C3',
#   'C4',
#   'C4',
#   'C5',
#   'C5',
#   'C6',
#   'C6',
#   'C6',
#   'C6',
#   'C7',
#   'C7',
#   'C7',
#   'C7',
#   'C7',
#   'C7',
#   'C8',
#   'C8',
#   'C8',
#   'C0',
#   'C0',
#   'C9',
#   'C9',
#   'C9',
#   'C9',
#   'C9',
#   'C1',
#   'C1',
#   'C1',
#   'C2',
#   'C2',
#   'C3',
#   'C3',
#   'C3',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C5',
#   'C5',
#   'C6',
#   'C6',
#   'C7',
#   'C7',
#   'C7',
#   'C8',
#   'C8',
#   'C9',
#   'C9',
#   'C9',
#   'C1',
#   'C1',
#   'C2',
#   'C2',
#   'C2',
#   'C3',
#   'C3',
#   'C4',
#   'C4',
#   'C5',
#   'C5',
#   'C5',
#   'C0',
#   'C6',
#   'C6',
#   'C6',
#   'C6',
#   'C6',
#   'C7',
#   'C7',
#   'C8',
#   'C8',
#   'C8',
#   'C8',
#   'C0',
#   'C9',
#   'C9',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C2',
#   'C2',
#   'C2',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C4',
#   'C4',
#   'C5',
#   'C5',
#   'C5',
#   'C6',
#   'C6',
#   'C7',
#   'C7',
#   'C0',
#   'C8',
#   'C8',
#   'C8',
#   'C0',
#   'C9',
#   'C9',
#   'C9',
#   'C0',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C2',
#   'C2',
#   'C2',
#   'C0',
#   'C3',
#   'C3',
#   'C3',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C5',
#   'C5',
#   'C6',
#   'C6',
#   'C7',
#   'C7',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C8',
#   'C8',
#   'C9',
#   'C9',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C2',
#   'C2',
#   'C2',
#   'C3',
#   'C3',
#   'C0',
#   'C0',
#   'C4',
#   'C4',
#   'C5',
#   'C5',
#   'C5',
#   'C6',
#   'C6',
#   'C7',
#   'C7',
#   'C8',
#   'C8',
#   'C9',
#   'C9',
#   'C9',
#   'C1',
#   'C1',
#   'C1',
#   'C2',
#   'C2',
#   'C3',
#   'C3',
#   'C3',
#   'C0',
#   'C4',
#   'C4',
#   'C0',
#   'C5',
#   'C5',
#   'C0',
#   'C6',
#   'C6',
#   'C7',
#   'C7',
#   'C8',
#   'C8',
#   'C8',
#   'C9',
#   'C9',
#   'C0',
#   'C1',
#   'C1',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C3',
#   'C3',
#   'C4',
#   'C4',
#   'C0',
#   'C5',
#   'C5',
#   'C5',
#   'C5',
#   'C0',
#   'C0',
#   'C0',
#   'C6',
#   'C6',
#   'C7',
#   'C7',
#   'C7',
#   'C7',
#   'C7',
#   'C7',
#   'C7',
#   'C0',
#   'C0',
#   'C8',
#   'C8',
#   'C8',
#   'C9',
#   'C9',
#   'C9',
#   'C1',
#   'C1',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C5',
#   'C5',
#   'C6',
#   'C6',
#   'C6',
#   'C7',
#   'C7',
#   'C8',
#   'C8',
#   'C9',
#   'C9',
#   'C9',
#   'C0',
#   'C0',
#   'C1',
#   'C1',
#   'C1',
#   'C2',
#   'C2',
#   'C3',
#   'C3',
#   'C3',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C5',
#   'C5',
#   'C5',
#   'C5',
#   'C5',
#   'C6',
#   'C6',
#   'C6',
#   'C7',
#   'C7',
#   'C0',
#   'C0',
#   'C8',
#   'C8',
#   'C9',
#   'C9',
#   'C1',
#   'C1',
#   'C2',
#   'C2',
#   'C3',
#   'C3',
#   'C4',
#   'C4',
#   'C5',
#   'C5',
#   'C6',
#   'C6',
#   'C7',
#   'C7',
#   'C7',
#   'C8',
#   'C8',
#   'C9',
#   'C9',
#   'C1',
#   'C1',
#   'C2',
#   'C2',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C3',
#   'C3',
#   'C3',
#   'C4',
#   'C4',
#   'C5',
#   'C5',
#   'C0',
#   'C0',
#   'C6',
#   'C6',
#   'C6',
#   'C7',
#   'C7',
#   'C0',
#   'C8',
#   'C8',
#   'C9',
#   'C9',
#   'C1',
#   'C1',
#   'C2',
#   'C2',
#   'C0',
#   'C3',
#   'C3',
#   'C4',
#   'C4',
#   'C0',
#   'C5',
#   'C5',
#   'C6',
#   'C6',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C7',
#   'C7',
#   'C0',
#   'C0',
#   'C8',
#   'C8',
#   'C9',
#   'C9',
#   'C0',
#   'C0',
#   'C1',
#   'C1',
#   'C2',
#   'C2',
#   'C3',
#   'C3',
#   'C4',
#   'C4',
#   'C5',
#   'C5',
#   'C6',
#   'C6',
#   'C0',
#   'C7',
#   'C7',
#   'C8',
#   'C8',
#   'C8',
#   'C9',
#   'C9',
#   'C1',
#   'C1',
#   'C2',
#   'C2',
#   'C3',
#   'C3',
#   'C4',
#   'C4',
#   'C0',
#   'C0',
#   'C5',
#   'C5',
#   'C0',
#   'C6',
#   'C6',
#   'C6',
#   'C7',
#   'C7',
#   'C0',
#   'C0',
#   'C0',
#   'C8',
#   'C8',
#   'C9',
#   'C9',
#   'C0',
#   'C1',
#   'C1',
#   'C2',
#   'C2',
#   'C3',
#   'C3',
#   'C4',
#   'C4',
#   'C5',
#   'C5',
#   'C6',
#   'C6',
#   'C7',
#   'C7',
#   'C8',
#   'C8',
#   'C0',
#   'C9',
#   'C9',
#   'C9',
#   'C0',
#   'C0',
#   'C1',
#   'C1',
#   'C0',
#   'C2',
#   'C2',
#   'C0',
#   'C3',
#   'C3',
#   'C4',
#   'C4',
#   'C5',
#   'C5',
#   'C6',
#   'C6',
#   'C6',
#   'C7',
#   'C7',
#   'C8',
#   'C8',
#   'C9',
#   'C9',
#   'C0',
#   'C1',
#   'C1',
#   'C2',
#   'C2',
#   'C3',
#   'C3',
#   'C4',
#   'C4',
#   'C5',
#   'C5',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C6',
#   'C6',
#   'C6',
#   'C6',
#   'C7',
#   'C7',
#   'C7',
#   'C7',
#   'C8',
#   'C8',
#   'C0',
#   'C9',
#   'C9',
#   'C9',
#   'C9',
#   'C9',
#   'C1',
#   'C1',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C3',
#   'C3',
#   'C4',
#   'C4',
#   'C5',
#   'C5',
#   'C5',
#   'C5',
#   'C5',
#   'C5',
#   'C5',
#   'C0',
#   'C6',
#   'C6',
#   'C6',
#   'C7',
#   'C7',
#   'C7',
#   'C8',
#   'C8',
#   'C8',
#   'C8',
#   'C8',
#   'C9',
#   'C9',
#   'C9',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C2',
#   'C2',
#   'C3',
#   'C3',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C5',
#   'C5',
#   'C5',
#   'C6',
#   'C6',
#   'C6',
#   'C6',
#   'C6',
#   'C6',
#   'C7',
#   'C7',
#   'C8',
#   'C8',
#   'C8',
#   'C9',
#   'C9',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C2',
#   'C2',
#   'C2',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C4',
#   'C4',
#   'C5',
#   'C5',
#   'C5',
#   'C6',
#   'C6',
#   'C6',
#   'C6',
#   'C6',
#   'C7',
#   'C7',
#   'C7',
#   'C7',
#   'C7',
#   'C8',
#   'C8',
#   'C9',
#   'C9',
#   'C9',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C2',
#   'C2',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C4',
#   'C4',
#   'C5',
#   'C5',
#   'C5',
#   'C5',
#   'C6',
#   'C6',
#   'C0',
#   'C7',
#   'C7',
#   'C7',
#   'C8',
#   'C8',
#   'C9',
#   'C9',
#   'C0',
#   'C1',
#   'C1',
#   'C2',
#   'C2',
#   'C2',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C0',
#   'C4',
#   'C4',
#   'C5',
#   'C5',
#   'C6',
#   'C6',
#   'C6',
#   'C7',
#   'C7',
#   'C7',
#   'C7',
#   'C8',
#   'C8',
#   'C9',
#   'C9',
#   'C1',
#   'C1',
#   'C1',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C2',
#   'C2',
#   'C2',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C4',
#   'C4',
#   'C4',
#   'C5',
#   'C5',
#   'C6',
#   'C6',
#   'C6',
#   'C6',
#   'C6',
#   'C7',
#   'C7',
#   'C7',
#   'C7',
#   'C7',
#   'C7',
#   'C8',
#   'C8',
#   'C8',
#   'C9',
#   'C9',
#   ...],
#  'order_rows': array(['1970', '2783', '2784', ..., '1889', '1886', '1902'], dtype='<U5'),
#  'labx': array([1545, 1390, 1612, ..., 3405, 3404, 3404], dtype=int32),
#  'max_d': 10,
#  'max_d_lower': None,
#  'max_d_upper': None,
#  'ax': <Axes: title={'center': 'Hierarchical Clustering Dendrogram'}, xlabel='Samples', ylabel='distance'>}

# %% [markdown]
# # DBSCAN Clustering

# %% [markdown]
# DBSCAN, which stands for Density-Based Spatial Clustering of Applications with Noise, is a popular density-based clustering algorithm in unsupervised machine learning. It is particularly useful for discovering clusters of arbitrary shapes in datasets with varying levels of data density. DBSCAN is known for its ability to handle noise and outliers effectively.
#
# As always, You can find additional information about how DBSCAN clustering works in the following article on Analytics Vidhya:
#
# [How DBSCAN Clustering Works](https://www.analyticsvidhya.com/blog/2020/09/how-dbscan-clustering-works/#:~:text=DBSCAN%20is%20a%20density%2Dbased,points%20into%20a%20single%20cluster.)
#
# This article provides a detailed explanation of DBSCAN, including its underlying concepts, the role of epsilon (ε) and minimum points (MinPts), and practical examples of how to use DBSCAN for clustering. It's a valuable resource for gaining a deeper understanding of the algorithm with Wikipedia as the side resource.

# %% [markdown]
# ### 2 Dimensional Visualization

# %%
from sklearn.neighbors import NearestNeighbors
neigh = NearestNeighbors(n_neighbors=2)
nbrs = neigh.fit(X_pca)
distances, indices = nbrs.kneighbors(X_pca)

# %%
distances = np.sort(distances, axis=0)
distances = distances[:,1]
plt.figure(figsize=(20,10))
plt.plot(distances)
plt.title('K-distance Graph',fontsize=20)
plt.xlabel('Data Points sorted by distance',fontsize=14)
plt.ylabel('Epsilon',fontsize=14)
plt.show()

# %%
# Perform DBSCAN clustering with interactive widget
def dbscan_clustering(eps, min_samples):
    dbscan = DBSCAN(eps=eps, min_samples=min_samples)
    dbscan.fit(X_pca)
    dbscan_labels = dbscan.labels_# Write Code here

    # Write the whole plotting part of the code
    plt.figure(figsize=(8, 6))
    plt.scatter(X_pca[:, 0], X_pca[:, 1], c=dbscan_labels, cmap='viridis', edgecolors='k')
    plt.xlabel('Feature 1 (Standardized)')
    plt.ylabel('Feature 2 (Standardized)')
    plt.title('DBSCAN Clustering')
    plt.legend()
    plt.show()

interact(dbscan_clustering, eps=(15,20,1), min_samples=(50,100,10)) # Fill here
# Out:
# interactive(children=(IntSlider(value=17, description='eps', max=20, min=15), IntSlider(value=70, description=…
# <function __main__.dbscan_clustering(eps, min_samples)>

# %% [markdown]
# ### 3 Dimensional Visualization

# %%
# Perform DBSCAN clustering with interactive widget
def dbscan_3d_clustering(eps, min_samples):
    # Write the whole code for the function
    dbscan_3d = DBSCAN(eps=eps, min_samples=min_samples)# Write Code Here
    dbscan_3d_labels = dbscan_3d.fit_predict(X_pca)# Write Code Here

    fig = plt.figure(figsize=(10, 8))
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(X_pca[:, 0], X_pca[:, 1], X_pca[:, 2], c=dbscan_3d_labels, cmap='viridis', edgecolors='k')
    ax.set_xlabel('Feature 1 (Standardized)')
    ax.set_ylabel('Feature 2 (Standardized)')
    ax.set_zlabel('Feature 3 (Standardized)')
    ax.set_title('DBSCAN Clustering (3D)')
    plt.show()

interact(dbscan_3d_clustering, eps=(15,20,1), min_samples=(1,10,1)) # Fill here
# Out:
# interactive(children=(IntSlider(value=17, description='eps', max=20, min=15), IntSlider(value=5, description='…
# <function __main__.dbscan_3d_clustering(eps, min_samples)>

# %% [markdown]
# # Mean Shift Clustering

# %% [markdown]
# It is a density-based clustering algorithm used in unsupervised machine learning and data analysis. Similar to DBSCAN, Mean Shift is capable of discovering clusters with arbitrary shapes and sizes in a dataset. It is particularly useful for applications where the number of clusters is not known in advance and when clusters have varying densities.
#
# For more hands-on information about the Mean Shift clustering algorithm, you can refer to this tutorial on Analytics India Magazine:
#
# [Hands-On Tutorial on Mean Shift Clustering Algorithm](https://analyticsindiamag.com/hands-on-tutorial-on-mean-shift-clustering-algorithm/)
#
# This tutorial provides practical insights into how to implement and use Mean Shift clustering, making it a valuable resource for those looking to apply this clustering technique to real-world data analysis and machine learning tasks especially in the sector of Image Segmentation.

# %% [markdown]
# ### 2 Dimensional Visualization

# %%
from sklearn.cluster import  estimate_bandwidth
bandwidth = estimate_bandwidth(X_pca, quantile=0.2, n_samples=500)
bandwidth
# Out:
# 18.980786167729587

# %%
# Perform Mean Shift clustering with interactive widget
def meanshift_clustering(n_band):
    mean_shift = MeanShift(bandwidth=n_band)
    mean_shift.fit(X_pca)
    cluster_centers = mean_shift.cluster_centers_
    mean_shift_labels = mean_shift.labels_
    cluster_label = np.unique(mean_shift_labels)
    n_clusters = len(cluster_label)
    print("Estimated number of clusters: ", n_clusters)
    # Write Code here

    # Write the whole plotting part of the code
    plt.figure(figsize=(8, 6))
    plt.scatter(X_pca[:, 0], X_pca[:, 1], c=mean_shift_labels, cmap='viridis', edgecolors='k')
    plt.xlabel('Feature 1 (Standardized)')
    plt.ylabel('Feature 2 (Standardized)')
    plt.title('Mean Shift Clustering')
    plt.legend()
    plt.show()

interact(meanshift_clustering, n_band=(16,20,1)) # Fill here
# Out:
# interactive(children=(IntSlider(value=18, description='n_band', max=20, min=16), Output()), _dom_classes=('wid…
# <function __main__.meanshift_clustering(n_band)>

# %% [markdown]
# ### 3 Dimensional Visualization

# %%
# Perform Mean Shift clustering with interactive widget
def meanshift_clustering(n_band):
    # Write the whole code for the function
    mean_shift_3d = MeanShift(bandwidth=n_band)
    mean_shift_3d.fit(X_pca)
    mean_shift_3d_labels = mean_shift_3d.labels_

    fig = plt.figure(figsize=(10, 8))
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(X_pca[:, 0], X_pca[:, 1], X_pca[:, 2], c=mean_shift_3d_labels, cmap='viridis', edgecolors='k')
    ax.set_xlabel('Feature 1 (Standardized)')
    ax.set_ylabel('Feature 2 (Standardized)')
    ax.set_zlabel('Feature 3 (Standardized)')
    ax.set_title('Mean Shift Clustering (3D)')
    plt.show()

interact(meanshift_clustering, n_band=(16,20,1))
# Out:
# interactive(children=(IntSlider(value=18, description='n_band', max=20, min=16), Output()), _dom_classes=('wid…
# <function __main__.meanshift_clustering(n_band)>

# %% [markdown]
# ***Congratulations! You have explored various clustering algorithms. Each algorithm has its own advantages and use cases. Remember, choosing the right algorithm and the right number of clusters is crucial. Feel free to experiment with different datasets and parameters to gain a better understanding.***

# %% [markdown]
# # **Bonus: To be done only if you have completed the above tasks.**

# %% [markdown]
# You can research and create a short blog on the topic of **Spectral Clustering Algortihm**. The best research will be edited and featured on the Synapse Instagram page. Happy coding! :)

# %% [markdown]
# #### Blog at: https://mlbeginnershandbook.blogspot.com/

# %% [markdown]
# # **End of Task**
#
# > ©DJS Synapse 2023 - 2024
